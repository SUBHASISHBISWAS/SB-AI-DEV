# %%
#!pip install openai

# %%
import openai
import os
from IPython.display import Image

# %%
Image('/Users/subhasish/Development/GIT/Interstellar/SB-AI-DEV/LLM-GPT/OpenAI/Udemy/Jose Portilla/OpenAI Python API Bootcamp-Learn to use AI, GPT3/SB/00-OpenAI-Setup/Images/2023-08-06_04-41-30.jpg')

# %%
#os.environ['OPENAI_API_KEY']=''
openai.api_key=os.getenv("OPENAI_API_KEY")

# %%
openai.Model.list()
# Out:
# <OpenAIObject list at 0x7facc86acef0> JSON: {
#   "object": "list",
#   "data": [
#     {
#       "id": "text-davinci-001",
#       "object": "model",
#       "created": 1649364042,
#       "owned_by": "openai",
#       "permission": [
#         {
#           "id": "modelperm-CDlahk1RbkghXDjtxqzXoPNo",
#           "object": "model_permission",
#           "created": 1690913868,
#           "allow_create_engine": false,
#           "allow_sampling": true,
#           "allow_logprobs": true,
#           "allow_search_indices": false,
#           "allow_view": true,
#           "allow_fine_tuning": false,
#           "organization": "*",
#           "group": null,
#           "is_blocking": false
#         }
#       ],
#       "root": "text-davinci-001",
#       "parent": null
#     },
#     {
#       "id": "text-search-curie-query-001",
#       "object": "model",
#       "created": 1651172509,
#       "owned_by": "openai-dev",
#       "permission": [
#         {
# ...

# %%
response=openai.Completion.create(model='text-davinci-003',
                                 prompt="Give me top 5 reason to Learn OpenAI in Python",
                                 max_tokens=300)

# %%
print(response['choices'][0]['text'])
# Out:
# 1. OpenAI allows developers and researchers to build models and algorithms that scale with raw compute power.
#
# 2. OpenAI provides developers with comprehensive control over machine-learning deployments.
#
# 3. OpenAI is built on TensorFlow which makes it an excellent platform for both deep learning and reinforcement learning.
#
# 4. OpenAI is an open source platform that makes it easy to share ideas and models with colleagues and the larger community.
#
# 5. OpenAI has one of the most advanced reinforcement-learning libraries available in Python.
