# %%
from IPython.display import Image

# %%
Image('/Users/subhasish/Documents/APPLE/SUBHASISH/Development/GIT/Interstellar/SB-AI-DEV/DL/Pluralsight/Janani Ravi/Building Deep Learning Models Using PyTorch/SB/Image/8/2023-04-06_12-42-07.jpg')

# %%
from tabulate import tabulate
def DisplayMatrix(M):
    print(tabulate(M, tablefmt='double_grid'))
