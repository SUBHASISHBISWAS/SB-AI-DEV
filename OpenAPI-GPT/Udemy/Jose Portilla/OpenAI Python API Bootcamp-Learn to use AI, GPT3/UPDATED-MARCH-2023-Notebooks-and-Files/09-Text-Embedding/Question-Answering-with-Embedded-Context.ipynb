# %% [markdown]
# <a href = "https://www.pieriantraining.com"><img src="../PT Centered Purple.png"> </a>
#
# <em style="text-align:center">Copyrighted by Pierian Training</em>

# %% [markdown]
# # Text Embedding API
#
# Text embedding allows us to directly convert text documents to vectors with a simple API call with Open AI.
#
# Keep in mind, just like other Open AI services, it is not free and it is also important to note it has its own pricing structure (its typically much cheaper than GPT on a token basis, since the processing is simpler). You can view the pricing here: https://openai.com/api/pricing/
#
# ## Imports

# %%
import openai 
import pandas as pd
import tiktoken # https://github.com/openai/tiktoken

# %%
openai.api_key = os.getenv("OPENAI_API_KEY")

# %% [markdown]
# ### What happens when GPT doesn't know anything about a topic?
#
# For example, we know GPT is limited by its training data not being up to date to the present day (depending on the model, the cut-off can be very recent though). There are also limitations based on how esoteric the topic is.
#
# Let's ask GPT about a a "unicorn" company

# %% [markdown]
# ---

# %%
prompt = "What does the start-up company Pentera do and who invested in it?"

response = openai.Completion.create(
    prompt=prompt,
    temperature=0,
    max_tokens=500,
    model="text-davinci-003"
)
print(response["choices"][0]["text"].strip(" \n"))
# Out:
# Pentera is a start-up company that provides software solutions to help organizations manage their employee benefits programs. The company has raised $3.5 million in seed funding from investors including Y Combinator, SV Angel, and Social Leverage.

# %% [markdown]
# While this may sound some what correct, the model is hallucinating! A common issue with LLMs, they are eager to please and with enough context they can make stuff up that sounds right, but actually isn't. In my personal research, it looks like Y Combinator did NOT actually invest in Pentera. Also Pentera isn't an HR company, Pentera is a penetration testing company that develops and provides an automated security validation platform to reduce cybersecurity risks.
#
# We could try to alleviate this issue with some prompt engineering:

# %%
prompt = """Only answer the question below if you have 100% certainty of the facts.

Q: What does the start-up company Pentera do and who invested in it?
A:"""


response = openai.Completion.create(
    prompt=prompt,
    temperature=0,
    max_tokens=500,
    model="text-davinci-003"
)
print(response["choices"][0]["text"].strip(" \n"))
# Out:
# I cannot answer this question with 100% certainty.

# %% [markdown]
# Alright, very interesting! How can we help the model? We could input some context from our own data. In fact, we have a data set about recent Unicorn companies.

# %% [markdown]
# ## Text Data
#
# Let's grab some text data and send it to Open AI to receive the embeddings back.

# %%
df = pd.read_csv("unicorns.csv")

# %%
df.head()
# Out:
#                Updated at     Company  \
# 0  10/31/2022, 2:37:05 AM       Esusu
# 1  10/31/2022, 2:37:05 AM  Fever Labs
# 2  10/31/2022, 2:37:04 AM       Minio
# 3  10/31/2022, 2:37:04 AM   Darwinbox
# 4  10/31/2022, 2:37:04 AM     Pentera
#
#                                   Crunchbase Url  Last Valuation (Billion $)  \
# 0       https://www.cbinsights.com/company/esusu                         1.0
# 1  https://www.cbinsights.com/company/fever-labs                         1.0
# 2       https://www.cbinsights.com/company/minio                         1.0
# 3   https://www.cbinsights.com/company/darwinbox                         1.0
# 4      https://www.cbinsights.com/company/pcysys                         1.0
#
#   Date Joined  Year Joined         City        Country  \
# 0   1/27/2022         2022     New York  United States
# 1   1/26/2022         2022     New York  United States
# 2   1/26/2022         2022    Palo Alto  United States
# 3   1/25/2022         2022    Hyderabad          India
# 4   1/11/2022         2022  Petah Tikva         Israel
#
#                        Industry  \
# 0                       Fintech
# 1  Internet software & services
# 2   Data management & analytics
# 3  Internet software & services
# 4                Cybersecurity
#
#                                            Investors  Company Website
# 0  ["Next Play Ventures","Zeal Capital Partners",...              NaN
# 1                        ["Accel","14W","GS Growth"]              NaN
# 2  ["General Catalyst","Nexus Venture Partners","...              NaN
# 3  ["Lightspeed India Partners","Sequoia Capital ...              NaN
# 4   ["AWZ Ventures","Blackstone","Insight Partners"]              NaN

# %% [markdown]
# Let's create a new column that summarizes each company with the information from the other columns

# %%
import ast 
def summary(company,crunchbase_url,city,country,industry,investor_list):
    investors = 'The investors in the company are'
     
    for investor in ast.literal_eval(investor_list):
        investors += f" {investor}, "

    text = f"{company} has headquarters in {city} in {country} and is in the field of {industry}. {investors}. You can find more information at {crunchbase_url}"

    return text

# %%
df['summary'] = df.apply(lambda df: summary(df['Company'],df['Crunchbase Url'],df['City'],df['Country'],df['Industry'],df['Investors']),axis=1)

# %%
df['summary'][0]
# Out:
# 'Esusu has headquarters in New York in United States and is in the field of Fintech. The investors in the company are Next Play Ventures,  Zeal Capital Partners,  SoftBank Group, . You can find more information at https://www.cbinsights.com/company/esusu'

# %%
df.head()
# Out:
#                Updated at     Company  \
# 0  10/31/2022, 2:37:05 AM       Esusu
# 1  10/31/2022, 2:37:05 AM  Fever Labs
# 2  10/31/2022, 2:37:04 AM       Minio
# 3  10/31/2022, 2:37:04 AM   Darwinbox
# 4  10/31/2022, 2:37:04 AM     Pentera
#
#                                   Crunchbase Url  Last Valuation (Billion $)  \
# 0       https://www.cbinsights.com/company/esusu                         1.0
# 1  https://www.cbinsights.com/company/fever-labs                         1.0
# 2       https://www.cbinsights.com/company/minio                         1.0
# 3   https://www.cbinsights.com/company/darwinbox                         1.0
# 4      https://www.cbinsights.com/company/pcysys                         1.0
#
#   Date Joined  Year Joined         City        Country  \
# 0   1/27/2022         2022     New York  United States
# 1   1/26/2022         2022     New York  United States
# 2   1/26/2022         2022    Palo Alto  United States
# 3   1/25/2022         2022    Hyderabad          India
# 4   1/11/2022         2022  Petah Tikva         Israel
#
#                        Industry  \
# 0                       Fintech
# 1  Internet software & services
# 2   Data management & analytics
# 3  Internet software & services
# 4                Cybersecurity
#
#                                            Investors  Company Website  \
# 0  ["Next Play Ventures","Zeal Capital Partners",...              NaN
# 1                        ["Accel","14W","GS Growth"]              NaN
# 2  ["General Catalyst","Nexus Venture Partners","...              NaN
# 3  ["Lightspeed India Partners","Sequoia Capital ...              NaN
# 4   ["AWZ Ventures","Blackstone","Insight Partners"]              NaN
#
#                                              summary
# 0  Esusu has headquarters in New York in United S...
# 1  Fever Labs has headquarters in New York in Uni...
# 2  Minio has headquarters in Palo Alto in United ...
# 3  Darwinbox has headquarters in Hyderabad in Ind...
# 4  Pentera has headquarters in Petah Tikva in Isr...

# %% [markdown]
# ### Token Count

# %% [markdown]
# In case you are ever worried about how many tokens your text actually has (to get an estimate of your costs) OpenAI has a library called "tiktoken", which allows you to estimate a cost based on token counts.
#
# Splitting text strings into tokens is useful because models like GPT-3 see text in the form of tokens. Knowing how many tokens are in a text string can tell you (a) whether the string is too long for a text model to process and (b) how much an OpenAI API call costs (as usage is priced by token). Different models use different encodings.
#
# **tiktoken** supports 3 different encodings for OpenAI models:
#
# * "gpt2" for most gpt-3 models
# * "p50k_base" for code models, and Davinci models, like "text-davinci-003"
# * "cl100k_base" for text-embedding-ada-002

# %%
import tiktoken

def num_tokens_from_string(string, encoding_name):
    """Returns the number of tokens in a text string."""
    encoding = tiktoken.get_encoding(encoding_name)
    num_tokens = len(encoding.encode(string))
    return num_tokens

# %% [markdown]
# Let's run a quick example on some text:

# %%
num_tokens_from_string(df['summary'][0],encoding_name='cl100k_base')
# Out:
# 58

# %% [markdown]
# Note how this is higher than the actual word count, this is because OpenAI tokens are not the same as words, remember things like punctuation and word length come into play, as a rough estimate, 1000 tokens is about 750 words. But with the tool above you can check your real token count before sending text over to OpenAI. Let's get a cost estimate of vectorizing our entire data set:

# %%
df['token_count'] = df['summary'].apply(lambda text: num_tokens_from_string(text,'cl100k_base'))

# %%
df.head()
# Out:
#                Updated at     Company  \
# 0  10/31/2022, 2:37:05 AM       Esusu
# 1  10/31/2022, 2:37:05 AM  Fever Labs
# 2  10/31/2022, 2:37:04 AM       Minio
# 3  10/31/2022, 2:37:04 AM   Darwinbox
# 4  10/31/2022, 2:37:04 AM     Pentera
#
#                                   Crunchbase Url  Last Valuation (Billion $)  \
# 0       https://www.cbinsights.com/company/esusu                         1.0
# 1  https://www.cbinsights.com/company/fever-labs                         1.0
# 2       https://www.cbinsights.com/company/minio                         1.0
# 3   https://www.cbinsights.com/company/darwinbox                         1.0
# 4      https://www.cbinsights.com/company/pcysys                         1.0
#
#   Date Joined  Year Joined         City        Country  \
# 0   1/27/2022         2022     New York  United States
# 1   1/26/2022         2022     New York  United States
# 2   1/26/2022         2022    Palo Alto  United States
# 3   1/25/2022         2022    Hyderabad          India
# 4   1/11/2022         2022  Petah Tikva         Israel
#
#                        Industry  \
# 0                       Fintech
# 1  Internet software & services
# 2   Data management & analytics
# 3  Internet software & services
# 4                Cybersecurity
#
#                                            Investors  Company Website  \
# 0  ["Next Play Ventures","Zeal Capital Partners",...              NaN
# 1                        ["Accel","14W","GS Growth"]              NaN
# 2  ["General Catalyst","Nexus Venture Partners","...              NaN
# 3  ["Lightspeed India Partners","Sequoia Capital ...              NaN
# 4   ["AWZ Ventures","Blackstone","Insight Partners"]              NaN
#
#                                              summary  token_count
# 0  Esusu has headquarters in New York in United S...           58
# 1  Fever Labs has headquarters in New York in Uni...           60
# 2  Minio has headquarters in Palo Alto in United ...           57
# 3  Darwinbox has headquarters in Hyderabad in Ind...           62
# 4  Pentera has headquarters in Petah Tikva in Isr...           58

# %% [markdown]
# ### Estimating Embedding Costs
#
# Let's now do a quick monetary estimate of how much this will all cost, currently ADA-002 embedding model costs $0.0004 / 1K tokens
#
# Pay careful attention, that isn't 4 cents per 1000 tokens, that would be $0.04, this is 1/100 of that cost, so quite "inexpensive" depending on your document workload.

# %% [markdown]
# So, let's estimate the cost:

# %%
df['token_count'].sum() * 0.0004 / 1000
# Out:
# 0.028168400000000003

# %% [markdown]
# Another thing to keep in mind is the size limit for embeddings, currently the ADA 002 model max token limit is 8191 tokens, let's quickly check against this limit:

# %%
df[df['token_count'] > 8191]
# Out:
# Empty DataFrame
# Columns: [Updated at, Company, Crunchbase Url, Last Valuation (Billion $), Date Joined, Year Joined, City, Country, Industry, Investors, Company Website, summary, token_count]
# Index: []

# %% [markdown]
# Looks like we're okay! It also looks like this will only cost us abou 3 cents to embed, not too bad!

# %% [markdown]
# ## Text Embedding
#
# To begin, we'll create a simple function to grab the embedding, in our case, we'll specify the ADA 002 model

# %%
def get_embedding(text):
  # Note how this function assumes you already set your Open AI key!
    result = openai.Embedding.create(
      model='text-embedding-ada-002',
      input=text
    )
    return result["data"][0]["embedding"]

# %% [markdown]
# ## Create Embeddings

# %% [markdown]
# Now to create the embeddings, we can simply call these functions, for example:

# %%
get_embedding(df['summary'][0])
# Out:
# [0.012057947926223278,
#  -0.017802061513066292,
#  -0.022373223677277565,
#  -0.034451279789209366,
#  -0.013807321898639202,
#  0.01033538393676281,
#  -0.016340898349881172,
#  0.025375980883836746,
#  0.0037467442452907562,
#  -0.02198447287082672,
#  0.01943749189376831,
#  -0.013076740317046642,
#  0.005415687337517738,
#  -0.016877105459570885,
#  0.01076434925198555,
#  -0.023780766874551773,
#  -0.0008374039898626506,
#  -0.023686930537223816,
#  0.0170647781342268,
#  0.0026877359487116337,
#  -0.023123912513256073,
#  -0.015724260360002518,
#  -0.009805879555642605,
#  0.021314214915037155,
#  -0.02210512012243271,
#  -0.0009475777624174953,
#  -0.011776438914239407,
#  -0.0014787574764341116,
#  -0.011628982611000538,
#  -0.011246935464441776,
#  0.011977517046034336,
#  -0.0036830694880336523,
#  -0.018968310207128525,
#  -0.004118737298995256,
#  -0.012687990441918373,
#  0.006142917554825544,
#  -0.02238662913441658,
#  0.014263097196817398,
#  0.019370466470718384,
#  -0.011816654354333878,
#  0.03174343332648277,
#  0.008733466267585754,
#  -0.014075425453484058,
#  0.0021012600045651197,
#  -0.028177659958600998,
#  0.013834131881594658,
#  -0.005261527840048075,
#  0.0023425528779625893,
#  0.005512875039130449,
#  0.03635481372475624,
#  -0.01022143941372633,
#  0.027561023831367493,
#  -0.019477708265185356,
#  0.011595468968153,
#  -0.007191872224211693,
#  -0.01012090127915144,
#  -0.005043693818151951,
#  -0.022547490894794464,
#  0.00854579359292984,
#  -0.00943053513765335,
#  0.005985407158732414,
#  0.006829932332038879,
#  -0.022292792797088623,
#  -0.018311457708477974,
#  -0.006102702114731073,
#  0.007795104756951332,
#  -0.025322360917925835,
#  -0.0038070674054324627,
#  0.004031604155898094,
#  0.006183132994920015,
#  0.019196199253201485,
#  0.021877232939004898,
#  -0.0019420735770836473,
#  0.009008272551000118,
#  0.005030288826674223,
#  -0.001354759675450623,
#  -0.02467891201376915,
#  -0.01012090127915144,
#  0.014289908111095428,
#  -0.0005056261434219778,
#  -0.0040383064188063145,
#  -0.010858185589313507,
#  -0.03429041802883148,
#  -0.007051117718219757,
#  0.01338505931198597,
#  0.02044287882745266,
#  -0.0028888133820146322,
#  0.023686930537223816,
#  -0.023606499657034874,
#  -0.0004947344423271716,
#  0.028418954461812973,
#  0.025148093700408936,
#  -0.004219276364892721,
#  -0.008914436213672161,
#  -0.045792050659656525,
#  0.036113519221544266,
#  -0.01978602632880211,
#  0.010241547599434853,
#  -0.01786908693611622,
#  -0.006253510247915983,
#  0.024008654057979584,
#  0.009557884186506271,
#  -0.00914902612566948,
#  -0.007922453805804253,
#  -0.020885249599814415,
#  0.004453866742551327,
#  -0.009524371474981308,
#  -0.01248021051287651,
#  0.031019555404782295,
#  -0.0006032325327396393,
#  -0.011830059811472893,
#  0.015469562262296677,
#  -0.01969218999147415,
#  0.008304500952363014,
#  0.02906240150332451,
#  -0.015147838741540909,
#  0.01577788218855858,
#  0.010771051980555058,
#  -0.016300683841109276,
#  -0.00874687172472477,
#  0.026904169470071793,
#  0.02467891201376915,
#  0.02510787732899189,
#  -0.0096919359639287,
#  0.018995121121406555,
#  0.006052433047443628,
#  -0.01394137367606163,
#  -0.018740423023700714,
#  -0.002851949306204915,
#  -0.022748569026589394,
#  0.024182921275496483,
#  -0.02107292227447033,
#  -0.007366138976067305,
#  0.018110379576683044,
#  -0.00478899572044611,
#  0.01054986659437418,
#  -0.017306070774793625,
#  0.01797632873058319,
#  -0.000850390293635428,
#  -0.0185527503490448,
#  0.03340567648410797,
#  0.00043608684791252017,
#  0.00126511265989393,
#  0.02006753534078598,
#  -0.0029709201771765947,
#  0.002344228560104966,
#  0.013291222974658012,
#  0.01989326812326908,
#  0.0077079711481928825,
#  -0.002396173542365432,
#  0.01479930430650711,
#  -0.03203834965825081,
#  -0.0052380687557160854,
#  -0.004406948573887348,
#  0.00667912419885397,
#  -0.0006912039243616164,
#  0.033137571066617966,
#  0.019772620871663094,
#  -0.013807321898639202,
#  -0.01063700020313263,
#  -0.031850676983594894,
#  0.009866203181445599,
#  -0.004691808484494686,
#  -0.01290917582809925,
#  0.009309888817369938,
#  0.02714546211063862,
#  0.009872904978692532,
#  -0.014088829979300499,
#  0.00031544032390229404,
#  -0.003900903509929776,
#  -0.027359945699572563,
#  0.024638697504997253,
#  -0.013820727355778217,
#  0.0016748079797253013,
#  0.00010294749517925084,
#  0.010938616469502449,
#  0.004567810799926519,
#  0.022467060014605522,
#  -0.02705162763595581,
#  -0.021193569526076317,
#  0.0450681708753109,
#  0.013606244698166847,
#  0.025657489895820618,
#  0.017399907112121582,
#  0.008646332658827305,
#  -0.01329792570322752,
#  0.014222881756722927,
#  0.0016907267272472382,
#  0.026488609611988068,
#  -0.01663581281900406,
#  0.020389258861541748,
#  0.011099478229880333,
#  0.002387795364484191,
#  -0.015925338491797447,
#  -0.6310080289840698,
#  -0.01646154560148716,
#  -0.0007712160004302859,
#  0.012761718593537807,
#  -0.00018128393276128918,
#  0.022668136283755302,
#  0.02697119489312172,
#  0.008606117218732834,
#  0.003622746327891946,
#  -0.002753086155280471,
#  -0.014678657986223698,
#  -0.015670640394091606,
#  -0.015054002404212952,
#  -0.013706782832741737,
#  -0.01958494819700718,
#  -0.014343529008328915,
#  -0.008907733485102654,
#  -0.051261357963085175,
#  0.002575467573478818,
#  -0.010938616469502449,
#  -0.003941119182854891,
#  0.018391888588666916,
#  0.004648241680115461,
#  -0.016099605709314346,
#  0.029303694143891335,
#  0.011602171696722507,
#  0.002536927815526724,
#  -0.021622534841299057,
#  -0.018164001405239105,
#  0.014155856333673,
#  -0.026300936937332153,
#  0.042440757155418396,
#  0.02687736041843891,
#  0.025014040991663933,
#  0.04101981222629547,
#  0.011729520745575428,
#  -0.01809697598218918,
#  0.01394137367606163,
#  -0.0060088662430644035,
#  0.023700334131717682,
#  -0.0008839031797833741,
#  -0.024169515818357468,
#  0.012037839740514755,
#  -0.013740296475589275,
#  0.01125363726168871,
#  0.03884817287325859,
#  0.02702481672167778,
#  -0.04152920842170715,
#  0.00918924156576395,
#  0.009370211511850357,
#  0.004031604155898094,
#  -0.02790955826640129,
#  -0.011789844371378422,
#  0.009611505083739758,
#  0.027333134785294533,
#  0.0006312995683401823,
#  -0.0062367538921535015,
#  -0.014062019996345043,
#  0.013076740317046642,
#  -0.014490985311567783,
#  -0.014692062512040138,
#  -0.005935137625783682,
#  -0.009484155103564262,
#  -0.02447783388197422,
#  -0.0367569662630558,
#  0.01168260257691145,
#  -0.018204215914011,
#  0.003108323086053133,
#  0.030965935438871384,
#  -0.00914902612566948,
#  0.0034585329703986645,
#  0.018874475732445717,
#  0.004427056293934584,
#  0.01900852657854557,
#  0.006809824611991644,
#  0.020456284284591675,
#  0.02717227302491665,
#  -0.011200017295777798,
#  -0.01179654709994793,
#  0.005358715541660786,
#  -0.011850167065858841,
#  -0.013163873925805092,
#  0.0009777393424883485,
#  -0.027212489396333694,
#  0.0019102363148704171,
#  -0.005700547248125076,
#  -0.01223891694098711,
#  -0.01202443428337574,
#  -0.0021532049868255854,
#  -0.010228142142295837,
#  0.015067407861351967,
#  0.006990794558078051,
#  -0.011481525376439095,
#  0.000924118678085506,
#  -0.0025788189377635717,
#  0.02075119875371456,
#  0.002419632626697421,
#  0.01125363726168871,
#  0.021408051252365112,
#  -0.00601221714168787,
#  0.0021934204269200563,
#  -0.003833877621218562,
#  0.003073134459555149,
#  0.0012383023276925087,
#  0.0183784831315279,
#  0.022976456210017204,
#  0.00043692465987987816,
#  -0.01219870150089264,
#  0.032762229442596436,
#  -0.060644976794719696,
#  -0.011159801855683327,
#  -0.02959860861301422,
#  -0.020737793296575546,
#  -0.0019705595914274454,
#  -0.004859372973442078,
#  -0.04426386207342148,
#  0.001105088391341269,
#  -0.008210664615035057,
#  0.0055765495635569096,
#  -0.0034266957081854343,
#  -0.001913587562739849,
#  -0.016126416623592377,
#  0.005851355381309986,
#  -0.0114212017506361,
#  0.015121027827262878,
#  0.004772239364683628,
#  -0.00957799144089222,
#  -0.005516225937753916,
#  -0.012976201251149178,
#  0.0009668476413935423,
#  -0.012071352452039719,
#  -0.04654273763298988,
#  0.002057693200185895,
#  -0.002282229717820883,
#  0.004219276364892721,
#  -0.00463148532435298,
#  0.008766978979110718,
#  -0.007144954055547714,
#  0.031153608113527298,
#  -0.021367836743593216,
#  -0.02490679919719696,
#  -0.009571288712322712,
#  0.015348915942013264,
#  -0.010368896648287773,
#  0.0007297437987290323,
#  -0.020147966220974922,
#  0.019102362915873528,
#  -0.012466805055737495,
#  -0.008438552729785442,
#  -0.013981589116156101,
#  -0.002751410473138094,
#  -0.00594854261726141,
#  0.00028004232444800436,
#  0.015844907611608505,
#  0.013230899348855019,
#  -0.012553938664495945,
#  -0.015268485061824322,
#  -0.017627794295549393,
#  -0.014129046350717545,
#  -0.014852925203740597,
#  0.006699231918901205,
#  0.018941501155495644,
#  -0.033941883593797684,
#  -0.015496373176574707,
#  -0.0213544312864542,
#  0.009678530506789684,
#  0.001918614492751658,
#  0.002310715615749359,
#  -0.02210512012243271,
#  0.010268357582390308,
#  -0.015322105959057808,
#  0.010368896648287773,
#  -0.003297670977190137,
#  0.016595596447587013,
#  0.03581860661506653,
#  0.015791285783052444,
#  -0.009035082533955574,
#  -0.00034434522967785597,
#  -0.003954524174332619,
#  -0.0011687630321830511,
#  0.018110379576683044,
#  0.0033848045859485865,
#  -0.01565723493695259,
#  0.01232605054974556,
#  0.01943749189376831,
#  -0.0010749268112704158,
#  0.011843465268611908,
#  0.018995121121406555,
#  0.005271581932902336,
#  -0.0074934884905815125,
#  -0.016300683841109276,
#  0.013043227605521679,
#  -0.02298986166715622,
#  0.015335510484874249,
#  0.010087387636303902,
#  0.021233784034848213,
#  0.010020362213253975,
#  0.004946506582200527,
#  0.00454435171559453,
#  0.007346031256020069,
#  0.019544733688235283,
#  0.0014242989709600806,
#  0.026032833382487297,
#  -0.018070165067911148,
#  -0.008297798223793507,
#  -0.027413565665483475,
#  -0.0003805810702033341,
#  -0.015509777702391148,
#  0.016019174829125404,
#  0.026300936937332153,
#  0.030188435688614845,
#  -0.023378610610961914,
#  -0.0008947948808781803,
#  0.0044572181068360806,
#  0.020429475232958794,
#  0.00863292720168829,
#  0.03557731211185455,
#  -0.011568658985197544,
#  -0.012976201251149178,
#  0.010851482860744,
#  -0.00564022408798337,
#  -0.012922581285238266,
#  0.01769481971859932,
#  -0.015523183159530163,
#  -0.011240232735872269,
#  0.021769991144537926,
#  0.04525584354996681,
#  0.026046238839626312,
#  0.008941246196627617,
#  -0.001881750300526619,
#  -0.00548941595479846,
#  0.02790955826640129,
#  -0.017024561762809753,
#  0.003961226902902126,
#  0.00469515984877944,
#  -0.02264132723212242,
#  0.037829380482435226,
#  -0.03927714005112648,
#  0.010596784763038158,
#  -0.013519111089408398,
#  0.027695074677467346,
#  0.003974631894379854,
#  0.04225308448076248,
#  -0.01339846383780241,
#  0.037373606115579605,
#  0.006072540767490864,
#  0.025751326233148575,
#  0.037293173372745514,
#  -0.03345929831266403,
#  0.004477325826883316,
#  -0.018365079537034035,
#  0.008780384436249733,
#  0.0032658337149769068,
#  -0.012748314067721367,
#  0.016622407361865044,
#  -0.018633181229233742,
#  -7.205277506727725e-05,
#  0.017279259860515594,
#  0.019571542739868164,
#  0.00564692635089159,
#  0.0021196920424699783,
#  -0.007795104756951332,
#  0.014558011665940285,
#  0.02642158418893814,
#  0.0076409452594816685,
#  -0.018190812319517136,
#  -0.01860637217760086,
#  -0.02916964329779148,
#  -0.016783269122242928,
#  -0.030483350157737732,
#  -0.014222881756722927,
#  -0.01437033899128437,
#  0.00043441119487397373,
#  0.007801807019859552,
#  0.020362447947263718,
#  -0.015080812387168407,
#  0.014665252529084682,
#  -0.022520679980516434,
#  0.015603614039719105,
#  -0.028365332633256912,
#  -0.0009492533863522112,
#  -0.04045679420232773,
#  0.013431977480649948,
#  0.01618003658950329,
#  0.023888006806373596,
#  -0.009450642392039299,
#  0.015764476731419563,
#  0.0023291476536542177,
#  -0.01752055250108242,
#  0.039491619914770126,
#  0.009383616968989372,
#  0.001152844401076436,
#  -0.02911602333188057,
#  -0.005445849150419235,
#  -0.009986849501729012,
#  0.011917193420231342,
#  0.04000101611018181,
#  -0.02193085290491581,
#  -0.0003608922124840319,
#  -0.018391888588666916,
#  0.024115895852446556,
#  -0.0160593893378973,
#  -0.020710982382297516,
#  0.0005848003784194589,
#  0.05667704716324806,
#  0.015161244198679924,
#  0.005747465416789055,
#  0.006548423785716295,
#  0.006910363677889109,
#  -0.021890638396143913,
#  0.00041199941188097,
#  -0.017882492393255234,
#  -0.04606015235185623,
#  0.026126669719815254,
#  -0.003639502916485071,
#  0.007312518544495106,
#  -0.014062019996345043,
#  -0.007366138976067305,
#  0.04147558659315109,
#  0.008753573521971703,
#  0.00031041339389048517,
#  -0.03418317437171936,
#  -0.028821108862757683,
#  0.019598353654146194,
#  0.11367581784725189,
#  0.006354049313813448,
#  -0.008706656284630299,
#  0.017735036090016365,
#  -0.0035020997747778893,
#  0.009055189788341522,
#  -0.018029948696494102,
#  -0.0556582510471344,
#  -0.01219870150089264,
#  0.007372841704636812,
#  -0.030965935438871384,
#  0.0024732532911002636,
#  0.00433657132089138,
#  -0.010965426452457905,
#  0.0023693633265793324,
#  0.0027212488930672407,
#  9.792055789148435e-05,
#  -0.017533957958221436,
#  3.746639413293451e-05,
#  -0.006783014629036188,
#  -0.011300555430352688,
#  0.002020828891545534,
#  0.026502015069127083,
#  0.03656929358839989,
#  0.03329843282699585,
#  0.01774844154715538,
#  0.01883425936102867,
#  0.033432487398386,
#  0.005053747911006212,
#  -0.014960166066884995,
#  0.012124973349273205,
#  -0.002020828891545534,
#  0.011783141642808914,
#  0.020456284284591675,
#  -0.045792050659656525,
#  -0.0002888394519686699,
#  0.017453527078032494,
#  0.01454460620880127,
#  0.007305815815925598,
#  0.007205277215689421,
#  -0.002642493462190032,
#  0.022547490894794464,
#  -0.0013405167264863849,
#  -0.013190683908760548,
#  0.00015960527525749058,
#  -0.027534212917089462,
#  -0.003897552378475666,
#  0.015603614039719105,
#  0.00802969466894865,
#  0.0020442879758775234,
#  0.01918279379606247,
#  -0.043298687785863876,
#  -0.03174343332648277,
#  -0.017788656055927277,
#  0.0011143045267090201,
#  -0.017614388838410378,
#  0.004112035036087036,
#  -0.016783269122242928,
#  -0.023888006806373596,
#  -0.0427088625729084,
#  -0.02327136881649494,
#  -0.012084757909178734,
#  -0.007332626264542341,
#  -0.017413312569260597,
#  0.012446697801351547,
#  -0.03383463993668556,
#  -0.013445382006466389,
#  -0.0005370444850996137,
#  -0.022896025329828262,
#  -0.02064395695924759,
#  0.02636796236038208,
#  -0.012801934033632278,
#  -0.015335510484874249,
#  0.01843210496008396,
#  0.052977219223976135,
#  -0.00448067719116807,
#  -0.003284265985712409,
#  0.0017678063595667481,
#  0.005556441843509674,
#  0.0354432612657547,
#  -0.009155728854238987,
#  0.005871463101357222,
#  -0.005522928666323423,
#  -0.0205233097076416,
#  -0.0019085606327280402,
#  0.002702816855162382,
#  0.024866584688425064,
#  -0.0012885716278105974,
#  -0.007453272584825754,
#  0.009450642392039299,
#  -0.007010902278125286,
#  -0.014437364414334297,
#  0.0043901922181248665,
#  -0.005080558359622955,
#  0.007124846335500479,
#  -0.0083581218495965,
#  0.019960293546319008,
#  -0.007607432082295418,
#  -0.008391634561121464,
#  -0.013706782832741737,
#  0.0006015568505972624,
#  -0.025443006306886673,
#  0.012875663116574287,
#  0.004195817280560732,
#  0.02084503509104252,
#  0.03512153774499893,
#  0.003249077359214425,
#  -0.009624909609556198,
#  -0.008606117218732834,
#  0.027963178232312202,
#  -0.001916938810609281,
#  -0.021005896851420403,
#  0.009142323397099972,
#  0.0003261225647293031,
#  -0.008123531006276608,
#  0.011588767170906067,
#  0.006719340104609728,
#  0.02112654224038124,
#  0.003255779854953289,
#  0.012419886887073517,
#  0.013847537338733673,
#  -0.0371055006980896,
#  0.024290163069963455,
#  0.016474949195981026,
#  0.018633181229233742,
#  -0.014638442546129227,
#  -0.0011377634946256876,
#  -0.015281890518963337,
#  -0.005221312399953604,
#  0.02407567948102951,
#  -0.03493386507034302,
#  0.024209732189774513,
#  -0.004326517693698406,
#  0.007265600375831127,
#  -0.0234992578625679,
#  -0.013619649223983288,
#  0.004229329992085695,
#  -0.004014847334474325,
#  0.013143765740096569,
#  -0.011427904479205608,
#  -0.004246086813509464,
#  -0.017560768872499466,
#  -0.004993424750864506,
#  -0.01883425936102867,
#  -0.012446697801351547,
#  -0.03168981522321701,
#  0.0004109521396458149,
#  0.009866203181445599,
#  0.016796674579381943,
#  0.00528163556009531,
#  -0.007607432082295418,
#  0.01809697598218918,
#  -0.005476010497659445,
#  0.0018415347440168262,
#  -0.007279005832970142,
#  -0.029786281287670135,
#  -0.019290035590529442,
#  -0.009651720523834229,
#  0.028418954461812973,
#  0.023083698004484177,
#  0.037293173372745514,
#  0.016247062012553215,
#  0.0011821681400761008,
#  -0.0026592500507831573,
#  0.010871590115129948,
#  -0.004259491804987192,
#  -0.01494676060974598,
#  0.01737309619784355,
#  0.00973215140402317,
#  0.016394518315792084,
#  0.02235981822013855,
#  0.0025905484799295664,
#  0.02296305075287819,
#  -0.03171662613749504,
#  -0.02951817773282528,
#  0.021568913012742996,
#  -0.0118367625400424,
#  -0.01351240836083889,
#  -0.03426360711455345,
#  -0.04477325826883316,
#  -0.022882619872689247,
#  -0.0069639841094613075,
#  -0.01479930430650711,
#  0.008994867093861103,
#  -0.050912823528051376,
#  -0.005874814465641975,
#  0.002719573210924864,
#  0.002964217448607087,
#  0.010020362213253975,
#  -0.010100793093442917,
#  0.019531328231096268,
#  -0.01646154560148716,
#  0.030510159209370613,
#  0.007017605006694794,
#  0.006246807985007763,
#  0.002461523748934269,
#  -0.004333220422267914,
#  -0.02089865505695343,
#  -0.0069237686693668365,
#  0.02714546211063862,
#  0.01832486316561699,
#  0.0068969582207500935,
#  0.015308700501918793,
#  0.006555126514285803,
#  -0.0009836041135713458,
#  0.02825809270143509,
#  -0.023298179730772972,
#  -0.003009459935128689,
#  0.03600627928972244,
#  -0.017533957958221436,
#  -0.011246935464441776,
#  0.0002509279584046453,
#  -0.017533957958221436,
#  -0.02992033213376999,
#  0.012473507784307003,
#  0.00594854261726141,
#  -0.015710854902863503,
#  0.018418699502944946,
#  -0.04938463494181633,
#  -4.731081207864918e-05,
#  -0.00772137613967061,
#  0.0046851057559251785,
#  0.021394645795226097,
#  0.008257582783699036,
#  0.02914283238351345,
#  0.03155576437711716,
#  0.018338268622756004,
#  -0.053352564573287964,
#  -0.018043354153633118,
#  -0.000957631622441113,
#  -0.0008231610408984125,
#  0.015308700501918793,
#  0.011119585484266281,
#  -0.013793916441500187,
#  -0.00411538640037179,
#  0.015134433284401894,
#  0.014102235436439514,
#  -0.01817740686237812,
#  0.0030044331215322018,
#  0.005375471897423267,
#  -0.009182539768517017,
#  0.018499130383133888,
#  -0.011742926202714443,
#  -0.01883425936102867,
#  -0.01597895845770836,
#  0.0063574002124369144,
#  -0.021716371178627014,
#  6.613564619328827e-05,
#  -0.010683918371796608,
#  -0.013847537338733673,
#  -0.006256861612200737,
#  0.01327111478894949,
#  -0.005848004017025232,
#  0.02092546597123146,
#  0.00500347837805748,
#  -0.004668349400162697,
#  -0.016783269122242928,
#  -0.0261668860912323,
#  -0.000997847062535584,
#  -0.02528214454650879,
#  -0.013927968218922615,
#  -0.006209943443536758,
#  -0.0015834852820262313,
#  0.009624909609556198,
#  0.006809824611991644,
#  0.007982776500284672,
#  -0.01475908886641264,
#  0.0038740932941436768,
#  0.004004793707281351,
#  0.02697119489312172,
#  -0.0035925847478210926,
#  -0.03244050219655037,
#  0.021662749350070953,
#  -0.008170449174940586,
#  0.009698638692498207,
#  -0.02390141226351261,
#  -0.021515293046832085,
#  -0.01321079209446907,
#  -0.004510838538408279,
#  -0.013807321898639202,
#  0.021113138645887375,
#  0.015482967719435692,
#  -0.0183784831315279,
#  -0.0010874941945075989,
#  -0.0009132269769906998,
#  -0.02018818072974682,
#  -0.01923641376197338,
#  0.005385525990277529,
#  0.01878063939511776,
#  0.0063741570338606834,
#  -0.011240232735872269,
#  -0.011179909110069275,
#  0.006608747411519289,
#  0.017989734187722206,
#  -0.0029725958593189716,
#  0.02530895546078682,
#  0.007922453805804253,
#  -0.001229924033395946,
#  -0.004453866742551327,
#  0.011642387136816978,
#  -0.013981589116156101,
#  0.019450897350907326,
#  -0.010013659484684467,
#  0.02508106641471386,
#  -0.007761591579765081,
#  -0.015911933034658432,
#  0.014450769871473312,
#  -0.01786908693611622,
#  0.005754167679697275,
#  0.007714673411101103,
#  0.008559199050068855,
#  0.0009735502535477281,
#  0.011863572522997856,
#  0.003175348974764347,
#  -0.0014913248596712947,
#  -0.003099944908171892,
#  0.005566495470702648,
#  -0.0030245408415794373,
#  -0.0033831289038062096,
#  0.015536588616669178,
#  -0.0031937810126692057,
#  -0.022453654557466507,
#  0.0038439317140728235,
#  -0.005928434897214174,
#  0.016769863665103912,
#  0.004990073386579752,
#  0.014826114289462566,
#  0.0025218469090759754,
#  -0.012714800424873829,
#  -0.0328158475458622,
#  -0.0061965384520590305,
#  -0.008813897147774696,
#  -0.021649343892931938,
#  -0.005750816781073809,
#  -0.00601221714168787,
#  -0.021139947697520256,
#  -0.006997497286647558,
#  -0.003441776614636183,
#  0.03219921141862869,
#  -0.014879735186696053,
#  -0.004212573636323214,
#  0.016568785533308983,
#  0.017761847004294395,
#  0.0025922241620719433,
#  0.004031604155898094,
#  -0.02006753534078598,
#  -0.033941883593797684,
#  -0.02264132723212242,
#  -0.029250074177980423,
#  -0.0018130488460883498,
#  -9.420271817361936e-05,
#  0.05018894374370575,
#  0.006819878704845905,
#  -0.023030076175928116,
#  -0.03466576337814331,
#  0.004075170960277319,
#  -0.06026963144540787,
#  0.007661052979528904,
#  -0.003864039434120059,
#  0.037775758653879166,
#  0.031421709805727005,
#  0.00844525545835495,
#  -0.009169134311378002,
#  -0.009470750577747822,
#  0.007386247161775827,
#  0.02009434439241886,
#  -0.04423705115914345,
#  0.003327832790091634,
#  0.02172977477312088,
#  -0.03286946937441826,
#  0.005268230568617582,
#  -0.018914690241217613,
#  -0.03284265846014023,
#  -0.0023693633265793324,
#  0.0183784831315279,
#  0.00011687629739753902,
#  0.011649089865386486,
#  0.022922836244106293,
#  -0.012078055180609226,
#  0.0062903743237257,
#  0.009008272551000118,
#  -0.000804728944785893,
#  -0.027721885591745377,
#  0.002992703579366207,
#  0.01966537907719612,
#  -0.04348636046051979,
#  0.0035188563633710146,
#  0.030215246602892876,
#  -0.020282017067074776,
#  -0.027989989146590233,
#  0.01660900190472603,
#  -0.013123658485710621,
#  -0.0014033534098416567,
#  0.005693844519555569,
#  -0.00792915653437376,
#  0.005593305919319391,
#  -0.03458533063530922,
#  -0.005462605506181717,
#  0.011696008034050465,
#  -0.018740423023700714,
#  0.009296483360230923,
#  0.023190937936306,
#  0.006786365527659655,
#  -0.0160593893378973,
#  -0.032333262264728546,
#  0.043727654963731766,
#  -0.021367836743593216,
#  0.00643448019400239,
#  -0.0019236414227634668,
#  -0.011568658985197544,
#  0.00433657132089138,
#  -0.010643702931702137,
#  -0.003612692467868328,
#  0.00820396188646555,
#  -0.018499130383133888,
#  -0.01561701949685812,
#  0.0019940186757594347,
#  -0.016340898349881172,
#  0.008619522675871849,
#  0.00317367329262197,
#  -0.01789589785039425,
#  -0.02674330770969391,
#  0.024866584688425064,
#  0.011260339990258217,
#  -0.019477708265185356,
#  -0.012393076904118061,
#  0.010389003902673721,
#  -0.02044287882745266,
#  -0.0043499767780303955,
#  -0.010415814816951752,
#  0.00780850974842906,
#  -0.029786281287670135,
#  -0.004313112236559391,
#  0.010610189288854599,
#  -0.02642158418893814,
#  0.03383463993668556,
#  0.19485750794410706,
#  0.014477579854428768,
#  0.007104738615453243,
#  0.036462053656578064,
#  -0.0023760658223181963,
#  0.008096721023321152,
#  0.019920077174901962,
#  0.005784329492598772,
#  -0.01978602632880211,
#  -0.004728672560304403,
#  -0.03721274435520172,
#  -0.012178594246506691,
#  0.0044974335469305515,
#  -0.0006597855826839805,
#  0.006360751576721668,
#  -0.024410808458924294,
#  -0.028311712667346,
#  -0.015724260360002518,
#  -0.009933228604495525,
#  0.028847919777035713,
#  0.002392822178080678,
#  -0.0047588343732059,
#  0.008565901778638363,
#  -0.023137317970395088,
#  0.02473253197968006,
#  0.004249437712132931,
#  0.0048225088976323605,
#  0.002793301595374942,
#  0.036542486399412155,
#  0.019651975482702255,
#  -0.01089169830083847,
#  0.02175658568739891,
#  0.016823483631014824,
#  0.016676027327775955,
#  -0.0026944384444504976,
#  -0.028579816222190857,
#  0.00987960770726204,
#  -0.014678657986223698,
#  0.023123912513256073,
#  0.008968056179583073,
#  0.0014226232888177037,
#  -0.013391762040555477,
#  -0.02788274735212326,
#  0.007654350250959396,
#  -0.015362321399152279,
#  0.014142450876533985,
#  ...]

# %% [markdown]
# Let's do the rest via our 2nd function:

# %%
# this will take awhile due to the amount of calls to the API.
# it will take about 0.5 seconds per row
df['embedding'] = df['summary'].apply(get_embedding)

# %%
df.head()
# Out:
#                Updated at     Company  \
# 0  10/31/2022, 2:37:05 AM       Esusu
# 1  10/31/2022, 2:37:05 AM  Fever Labs
# 2  10/31/2022, 2:37:04 AM       Minio
# 3  10/31/2022, 2:37:04 AM   Darwinbox
# 4  10/31/2022, 2:37:04 AM     Pentera
#
#                                   Crunchbase Url  Last Valuation (Billion $)  \
# 0       https://www.cbinsights.com/company/esusu                         1.0
# 1  https://www.cbinsights.com/company/fever-labs                         1.0
# 2       https://www.cbinsights.com/company/minio                         1.0
# 3   https://www.cbinsights.com/company/darwinbox                         1.0
# 4      https://www.cbinsights.com/company/pcysys                         1.0
#
#   Date Joined  Year Joined         City        Country  \
# 0   1/27/2022         2022     New York  United States
# 1   1/26/2022         2022     New York  United States
# 2   1/26/2022         2022    Palo Alto  United States
# 3   1/25/2022         2022    Hyderabad          India
# 4   1/11/2022         2022  Petah Tikva         Israel
#
#                        Industry  \
# 0                       Fintech
# 1  Internet software & services
# 2   Data management & analytics
# 3  Internet software & services
# 4                Cybersecurity
#
#                                            Investors  Company Website  \
# 0  ["Next Play Ventures","Zeal Capital Partners",...              NaN
# 1                        ["Accel","14W","GS Growth"]              NaN
# 2  ["General Catalyst","Nexus Venture Partners","...              NaN
# 3  ["Lightspeed India Partners","Sequoia Capital ...              NaN
# 4   ["AWZ Ventures","Blackstone","Insight Partners"]              NaN
#
#                                              summary  token_count  \
# 0  Esusu has headquarters in New York in United S...           58
# 1  Fever Labs has headquarters in New York in Uni...           60
# 2  Minio has headquarters in Palo Alto in United ...           57
# 3  Darwinbox has headquarters in Hyderabad in Ind...           62
# 4  Pentera has headquarters in Petah Tikva in Isr...           58
#
#                                            embedding
# 0  [0.01195491198450327, -0.017717931419610977, -...
# 1  [0.009171437472105026, 0.01314949057996273, -0...
# 2  [0.002730059437453747, -0.03737899661064148, 0...
# 3  [-0.0024771858006715775, -0.024587858468294144...
# 4  [0.011331121437251568, -0.011193273589015007, ...

# %%
df.to_csv('unicorns_with_embeddings.csv',index=False)

# %% [markdown]
# ## Document Similarity
#
# We can now take a new string, embed it into a vector, and perform a cosine similarity search against all the vector embeddings in our DataFrame:

# %%
prompt = "What does the company Pentera do and who invested in it?"

# %%
prompt_embedding = get_embedding(prompt)

# %%
import numpy as np
# There are other services/programs for larger amount of vectors
# Take a look at vector search engines like Pinecone or Weaviate
def vector_similarity(vec1,vec2):
    """
    Returns the similarity between two vectors.
    
    Because OpenAI Embeddings are normalized to length 1, the cosine similarity is the same as the dot product.
    """
    return np.dot(np.array(vec1), np.array(vec2))

# %%
df["prompt_similarity"] = df['embedding'].apply(lambda vector: vector_similarity(vector, prompt_embedding))

# %%
df.sort_values("prompt_similarity", ascending=False).head()
# Out:
#                   Updated at                Company  \
# 4     10/31/2022, 2:37:04 AM                Pentera
# 933   10/31/2022, 2:34:02 AM                  Pendo
# 61    10/31/2022, 2:36:13 AM           Perimeter 81
# 1183  10/31/2022, 2:33:34 AM  Intarcia Therapeutics
# 988   10/31/2022, 2:36:23 AM                Momenta
#
#                                          Crunchbase Url  \
# 4             https://www.cbinsights.com/company/pcysys
# 933          https://www.cbinsights.com/company/pendoio
# 61      https://www.cbinsights.com/company/perimeter-81
# 1183  https://www.cbinsights.com/company/intarcia-th...
# 988          https://www.cbinsights.com/company/momenta
#
#       Last Valuation (Billion $) Date Joined  Year Joined         City  \
# 4                            1.0   1/11/2022         2022  Petah Tikva
# 933                          2.6  10/17/2019         2019      Raleigh
# 61                           1.0    6/6/2022         2022     Tel Aviv
# 1183                         3.8    4/1/2014         2014       Boston
# 988                          1.0  10/17/2018         2018      Beijing
#
#             Country                      Industry  \
# 4            Israel                Cybersecurity
# 933   United States  Internet software & services
# 61           Israel                 Cybersecurity
# 1183  United States                        Health
# 988           China       Artificial intelligence
#
#                                               Investors  Company Website  \
# 4      ["AWZ Ventures","Blackstone","Insight Partners"]              NaN
# 933   ["Contour Venture Partners","Battery Ventures"...              NaN
# 61    ["Insight Partners","Toba Capital","Spring Ven...              NaN
# 1183  ["New Enterprise Associates","New Leaf Venture...              NaN
# 988   ["Sinovation Ventures","Tencent Holdings","Seq...              NaN
#
#                                                 summary  token_count  \
# 4     Pentera has headquarters in Petah Tikva in Isr...           58
# 933   Pendo has headquarters in Raleigh in United St...           59
# 61    Perimeter 81 has headquarters in Tel Aviv in I...           57
# 1183  Intarcia Therapeutics has headquarters in Bost...           62
# 988   Momenta has headquarters in Beijing in China a...           55
#
#                                               embedding  prompt_similarity
# 4     [0.011331121437251568, -0.011193273589015007, ...           0.883279
# 933   [0.01703517511487007, -0.0028536927420645952, ...           0.826227
# 61    [0.006611596792936325, -0.0017099825199693441,...           0.819634
# 1183  [0.016609707847237587, -0.002032819902524352, ...           0.804336
# 988   [0.0063818651251494884, -0.03462127968668938, ...           0.803542

# %% [markdown]
# Now we can easily grab the summary for the most similar embedding, then insert that as context to our GPT request!

# %%
# Could also use sort_values() with ascending=False, but nlargest should be more performant
df.nlargest(1,'prompt_similarity').iloc[0]['summary']
# Out:
# 'Pentera has headquarters in Petah Tikva in Israel and is in the field of Cybersecurity . The investors in the company are AWZ Ventures,  Blackstone,  Insight Partners, . You can find more information at https://www.cbinsights.com/company/pcysys'

# %% [markdown]
# ## Question Answering with Embeddings

# %% [markdown]
# Let's try inserting the summary to help the model to see if it actually helps:

# %%
summary = df.nlargest(1,'prompt_similarity').iloc[0]['summary']

# %%
prompt = f"""Only answer the question below if you have 100% certainty of the facts, use the context below to answer.
Here is some context:
{summary}
Q: What does the start-up company Pentera do and who invested in it?
A:"""


response = openai.Completion.create(
    prompt=prompt,
    temperature=0,
    max_tokens=500,
    model="text-davinci-003"
)
print(response["choices"][0]["text"].strip(" \n"))
# Out:
# Pentera is a start-up company in the field of Cybersecurity with headquarters in Petah Tikva, Israel. The investors in the company are AWZ Ventures, Blackstone, and Insight Partners.

# %% [markdown]
# Nice! Let's clean this all up by creating a function that wraps all the functions together. Note how this is pretty limited due to our data, but hopefully you can see how this is generalizable to your own data sets and prompts, each situation will be different!

# %%
def embed_prompt_lookup():
    # initial question
    question = input("What question do you have about a Unicorn company? ")
    # Get embedding
    prompt_embedding = get_embedding(question)
    # Get prompt similarity with embeddings
    # Note how this will overwrite the prompt similarity column each time!
    df["prompt_similarity"] = df['embedding'].apply(lambda vector: vector_similarity(vector, prompt_embedding))

    # get most similar summary
    summary = df.nlargest(1,'prompt_similarity').iloc[0]['summary'] 

    prompt = f"""Only answer the question below if you have 100% certainty of the facts, use the context below to answer.
            Here is some context:
            {summary}
            Q: {question}
            A:"""


    response = openai.Completion.create(
        prompt=prompt,
        temperature=0,
        max_tokens=500,
        model="text-davinci-003"
    )
    print(response["choices"][0]["text"].strip(" \n"))

# %%
embed_prompt_lookup()
# Out:
# Momenta is a company in the field of Artificial Intelligence with headquarters in Beijing, China.
