# %% [markdown]
# # Graded Lab: Agentic Workflows
#
# In this lab, you will build an agentic system that generates a short research report through planning, external tool usage, and feedback integration. Your workflow will involve:
#
# ### Agents
#
# * **Planning Agent / Writer**: Creates an outline and coordinates tasks.
# * **Research Agent**: Gathers external information using tools like Arxiv, Tavily, and Wikipedia.
# * **Editor Agent**: Reflects on the report and provides suggestions for improvement.

# %% [markdown]
# ---
# <a name='submission'></a>
#
# <h4 style="color:green; font-weight:bold;">TIPS FOR SUCCESSFUL GRADING OF YOUR ASSIGNMENT:</h4>
#
# * All cells are frozen except for the ones where you need to write your solution code or when explicitly mentioned you can interact with it.
#
# * In each exercise cell, look for comments `### START CODE HERE ###` and `### END CODE HERE ###`. These show you where to write the solution code. **Do not add or change any code that is outside these comments**.
#
# * You can add new cells to experiment but these will be omitted by the grader, so don't rely on newly created cells to host your solution code, use the provided places for this.
#
# * Avoid using global variables unless you absolutely have to. The grader tests your code in an isolated environment without running all cells from the top. As a result, global variables may be unavailable when scoring your submission. Global variables that are meant to be used will be defined in UPPERCASE.
#
# * To submit your notebook for grading, first save it by clicking the 💾 icon on the top left of the page and then click on the <span style="background-color: #0056D2; color: white; padding: 3px 5px; font-size: 16px; border-radius: 5px;">Submit assignment</span> button on the top right of the page.
# ---

# %% [markdown]
# ### Research Tools
#
# By importing `research_tools`, you gain access to several search utilities:
#
# - `research_tools.arxiv_search_tool(query)` → search academic papers from **arXiv**
#
#   *Example:* `research_tools.arxiv_search_tool("neural networks for climate modeling")`
#
# - `research_tools.tavily_search_tool(query)` → perform web searches with the **Tavily API**
#
#   *Example:* `research_tools.tavily_search_tool("latest trends in sunglasses fashion")`
#
# - `research_tools.wikipedia_search_tool(query)` → retrieve summaries from **Wikipedia**
#
#   *Example:* `research_tools.wikipedia_search_tool("Ensemble Kalman Filter")`
#
# Run the cell below to make them available.

# %%
# =========================
# Imports
# =========================

# --- Standard library 
from datetime import datetime
import re
import json
import ast


# --- Third-party ---
from IPython.display import Markdown, display
from aisuite import Client

# --- Local / project ---
import research_tools

# %%
import unittests

# %% [markdown]
# ### Initialize client
#
# Create a shared client instance for upcoming calls.

# %%
CLIENT = Client()

# %% [markdown]
# ## Exercise 1: planner_agent
#
# ### Objective
# Correctly set up a call to a language model (LLM) to generate a research plan.
#
# ### Instructions
#
# 1. **Focus Areas**:
#    - Ensure `CLIENT.chat.completions.create` is correctly configured.
#    - Pass the `model` and `messages` parameters correctly:
#      - **Model**: Use `"openai:o4-mini"` by default.
#      - **Messages**: Set with `{"role": "user", "content": user_prompt}`.
#      - **Temperature**: Fixed at 1 for creative outputs.
#
# ### Notes
#
# - The prompt is pre-defined and guides the LLM on task requirements.
# - Only return a formatted list of steps — no extra text.
#
# Focus on the LLM call setup to complete the task.

# %%
# GRADED FUNCTION: planner_agent

def planner_agent(topic: str, model: str = "openai:o4-mini") -> list[str]:
    """
    Generates a plan as a Python list of steps (strings) for a research workflow.

    Args:
        topic (str): Research topic to investigate.
        model (str): Language model to use.

    Returns:
        List[str]: A list of executable step strings.
    """

    
    # Build the user prompt
    user_prompt = f"""
    You are a planning agent responsible for organizing a research workflow with multiple intelligent agents.

    🧠 Available agents:
    - A research agent who can search the web, Wikipedia, and arXiv.
    - A writer agent who can draft research summaries.
    - An editor agent who can reflect and revise the drafts.

    🎯 Your job is to write a clear, step-by-step research plan **as a valid Python list**, where each step is a string.
    Each step should be atomic, executable, and must rely only on the capabilities of the above agents.

    🚫 DO NOT include irrelevant tasks like "create CSV", "set up a repo", "install packages", etc.
    ✅ DO include real research-related tasks (e.g., search, summarize, draft, revise).
    ✅ DO assume tool use is available.
    ✅ DO NOT include explanation text — return ONLY the Python list.
    ✅ The final step should be to generate a Markdown document containing the complete research report.

    Topic: "{topic}"
    """

    # Add the user prompt to the messages list
    messages = [{"role": "user", "content": user_prompt}]

    ### START CODE HERE ###

    # Call the LLM
    response = CLIENT.chat.completions.create( 
        # Pass in the model
        model=model,
        # Define the messages. Remember this is meant to be a user prompt!
        messages=messages,
        # Keep responses creative
        temperature=1, 
    )

    ### END CODE HERE ###

    # Extract message from response
    steps_str = response.choices[0].message.content.strip()

    # Parse steps
    steps = ast.literal_eval(steps_str)

    return steps

# %%
# Test your code!
unittests.test_planner_agent(planner_agent)
# Out:
#  All tests passed!

# %% [markdown]
# ## Exercise 2: research_agent
#
# ### Objective
# Set up a call to a language model (LLM) to perform a research task using various tools.
#
# ### Instructions
#
# **Focus Areas**:
#
# - **Creating a Custom Prompt**:
#   - **Define the Role**: Clearly specify the role, such as "research assistant."
#   - **List Available Tools** (as strings inside the prompt, not the actual functions):
#     - Use `arxiv_tool` to find academic papers.
#     - Use `tavily_tool` for general web searches.
#     - Use `wikipedia_tool` for accessing encyclopedic knowledge.
#   - **Specify the Task**: Include a placeholder in your prompt for defining the specific task that needs to be accomplished.
#   - **Include Date Information**: Add a placeholder for the current date or time to provide context.
#
# - **Creating Messages Dict**:
#   - Ensure the `messages` are correctly set with `{"role": "user", "content": prompt}`.
#
# - **Creating Tools List**:
#   - Create a list of tools for use, such as `research_tools.arxiv_search_tool`, `research_tools.tavily_search_tool`, and `research_tools.wikipedia_search_tool`.
#
# - **Correctly Setting the Call to the LLM**:
#   - Pass the `model`, `messages`, and `tools` parameters accurately.
#   - Set `tool_choice` to `"auto"` for automatic tool selection.
#   - Limit interactions with `max_turns=6`.
#
# ### Notes
#
# - The function provides pre-coded blocks where you need to replace placeholder values.
# - The approach allows the LLM to use tools dynamically based on the task.
#
# Focus on accurately setting the messages, tools, and LLM call parameters to complete the task.

# %%
# GRADED FUNCTION: research_agent

def research_agent(task: str, model: str = "openai:gpt-4o", return_messages: bool = False):
    """
    Executes a research task using tools via aisuite (no manual loop).
    Returns either the assistant text, or (text, messages) if return_messages=True.
    """
    print("==================================")  
    print("🔍 Research Agent")                 
    print("==================================")

    current_time = datetime.now().strftime('%Y-%m-%d')
    
    ### START CODE HERE ###

    # Create a customizable prompt by defining the role (e.g., "research assistant"),
    # listing tools (arxiv_tool, tavily_tool, wikipedia_tool) for various searches,
    # specifying the task with a placeholder, and including a current_time placeholder.
    prompt = f"""You are a research assistant.
Today's date is {current_time}.
You have access to the following tools:
- arxiv_tool: to search academic papers on arXiv.
- tavily_tool: for general web searches.
- wikipedia_tool: for accessing encyclopedic knowledge.

Task:
{task}"""
    
    # Create the messages dict to pass to the LLM. Remember this is a user prompt!
    messages = [{"role": "user", "content": prompt}]

    # Save all of your available tools in the tools list. These can be found in the research_tools module.
    # You can identify each tool in your list like this: 
    # research_tools.<name_of_tool>, where <name_of_tool> is replaced with the function name of the tool.
    tools = [
        research_tools.arxiv_search_tool,
        research_tools.tavily_search_tool,
        research_tools.wikipedia_search_tool,
    ]
    
    # Call the model with tools enabled
    response = CLIENT.chat.completions.create(  
        # Set the model
        model=model,
        # Pass in the messages. You already defined this!
        messages=messages,
        # Pass in the tools list. You already defined this!
        tools=tools,
        # Set the LLM to automatically choose the tools
        tool_choice="auto",
        # Set the max turns to 6
        max_turns=6
    )  
    
    ### END CODE HERE ###

    content = response.choices[0].message.content
    print("✅ Output:\n", content)

    
    return (content, messages) if return_messages else content

# %%
# Test your code!
unittests.test_research_agent(research_agent)
# Out:
# ==================================
# 🔍 Research Agent
# ==================================
# ✅ Output:
#  Please provide me with the topic or subject for which you need the references, so I can assist you better.
# ==================================
# 🔍 Research Agent
# ==================================
# ✅ Output:
#  The concept of seminal papers encompasses groundbreaking and influential research works that significantly advance a field. One such paper highlighted is "On a Seminal Paper by Karlin and McGregor," which discusses foundational developments in probability and mathematical analysis, indicating the profound impact of such contributions on mathematical theories and methods. Another noteworthy study is "Discovering Seminal Works with Marker Papers," focusing on identifying pivotal contributions across disciplines by analyzing their bibliometric impact, underscoring the historical significance and guiding role of seminal papers in academia. These papers illustrate foundational developments across mathematics and information retrieval, showcasing how seminal works guide and inspire ongoing research, shaping the landscape of scientific inquiry.
#  All tests passed!

# %% [markdown]
# ## Exercise 3: writer_agent
#
# ### Objective
# Set up a call to a language model (LLM) for executing writing tasks like drafting, expanding, or summarizing text.
#
# ### Instructions
#
# 1. **Focus Areas**:
#    - **System Prompt**:
#      - Define `system_prompt` to assign the LLM the role of a writing agent focused on generating academic or technical content.
#    - **System and User Messages**:
#      - Create `system_msg` using `{"role": "system", "content": system_prompt}`.
#      - Create `user_msg` using `{"role": "user", "content": task}`.
#    - **Messages List**:
#      - Combine `system_msg` and `user_msg` into a `messages` list.
#
# ### Notes
#
# - The function is designed to produce well-structured text by setting the correct prompts.
# - Temperature is set to 1.0 to allow for creative variance in the writing outputs.
#
# Ensure the system prompt and messages are defined properly to achieve a structured output from the LLM.

# %%
# GRADED FUNCTION: writer_agent
def writer_agent(task: str, model: str = "openai:gpt-4o") -> str:
    """
    Executes writing tasks, such as drafting, expanding, or summarizing text.
    """
    print("==================================")
    print("✍️ Writer Agent")
    print("==================================")

    ### START CODE HERE ###
    
    # Create the system prompt.
    # This should assign the LLM the role of a writing agent specialized in generating well-structured academic or technical content
    system_prompt = "You are a writing agent specialized in generating well-structured academic or technical content."

    # Define the system msg by using the system_prompt and assigning the role of system
    system_msg = {"role": "system", "content": system_prompt}

    # Define the user msg. In this case the user prompt should be the task passed to the function
    user_msg = {"role": "user", "content": task}

    # Add both system and user messages to the messages list
    messages = [system_msg, user_msg]
    
    ### END CODE HERE ###

    response = CLIENT.chat.completions.create(
        model=model, 
        messages=messages,
        temperature=1.0
    )

    return response.choices[0].message.content

# %%
# Test your code!
unittests.test_writer_agent(writer_agent)
# Out:
# ==================================
# ✍️ Writer Agent
# ==================================
#  All tests passed!

# %% [markdown]
# ## Exercise 4: editor_agent
#
# ### Objective
# Configure a call to a language model (LLM) to perform editorial tasks such as reflecting, critiquing, or revising drafts.
#
# ### Instructions
#
# 1. **Focus Areas**:
#    - **System Prompt**:
#      - Define `system_prompt` to assign the LLM the role of an editor agent whose task is to reflect on, critique, or improve drafts.
#    - **System and User Messages**:
#      - Create `system_msg` using `{"role": "system", "content": system_prompt}`.
#      - Create `user_msg` using `{"role": "user", "content": task}`.
#    - **Messages List**:
#      - Combine `system_msg` and `user_msg` into a `messages` list.
#
# ### Notes
#
# - The editor agent is tailored for enhancing the quality of text by setting an appropriate role and task in the prompts.
# - Temperature is set to 0.7, balancing creativity and coherence in editorial outputs.
#
# Ensure the system prompt and messages are accurately set up to perform effective editorial tasks with the LLM.

# %%
# GRADED FUNCTION: editor_agent
def editor_agent(task: str, model: str = "openai:gpt-4o") -> str:
    """
    Executes editorial tasks such as reflection, critique, or revision.
    """
    print("==================================")
    print("🧠 Editor Agent")
    print("==================================")
    
    ### START CODE HERE ###

    # Create the system prompt.
    # This should assign the LLM the role of an editor agent specialized in reflecting on, critiquing, or improving existing drafts.
    system_prompt = "You are an editor agent specialized in reflecting on, critiquing, or improving existing drafts."
    
    # Define the system msg by using the system_prompt and assigning the role of system
    system_msg = {"role": "system", "content": system_prompt}
    
    # Define the user msg. In this case the user prompt should be the task passed to the function
    user_msg = {"role": "user", "content": task}
    
    # Add both system and user messages to the messages list
    messages = [system_msg, user_msg]
    
    ### END CODE HERE ###
    
    response = CLIENT.chat.completions.create(
        model=model, 
        messages=messages,
        temperature=0.7 
    )
    
    return response.choices[0].message.content

# %%
# Test your code!
unittests.test_editor_agent(editor_agent)
# Out:
# ==================================
# 🧠 Editor Agent
# ==================================
#  All tests passed!

# %% [markdown]
# ### 🎯 The Executor Agent
#
# The `executor_agent` manages the workflow by executing each step of a given plan. It:
#
# 1. Decides **which agent** (`research_agent`, `writer_agent`, or `editor_agent`) should handle the step.
# 2. Builds context from the outputs of previous steps.
# 3. Sends the enriched task to the selected agent.
# 4. Collects and stores the results in a shared history.
#
# 👉 **Do not implement or modify this function.** It is already provided as the orchestration component of the multi-agent pipeline.
#
# Notice that `planner_agent` might return a long list of steps. Because of this, the maximum number of steps is set to a maximum of 4 to keep running time reasonable.

# %%
agent_registry = {
    "research_agent": research_agent,
    "editor_agent": editor_agent,
    "writer_agent": writer_agent,
}

def clean_json_block(raw: str) -> str:
    """
    Clean the contents of a JSON block that may come wrapped with Markdown backticks.
    """
    raw = raw.strip()
    if raw.startswith("```"):
        raw = re.sub(r"^```(?:json)?\n?", "", raw)
        raw = re.sub(r"\n?```$", "", raw)
    return raw.strip()

# %%
def executor_agent(topic, model: str = "openai:gpt-4o", limit_steps: bool = True):

    plan_steps = planner_agent(topic)
    max_steps = 4

    if limit_steps:
        plan_steps = plan_steps[:min(len(plan_steps), max_steps)]
    
    history = []

    print("==================================")
    print("🎯 Editor Agent")
    print("==================================")

    for i, step in enumerate(plan_steps):

        agent_decision_prompt = f"""
        You are an execution manager for a multi-agent research team.

        Given the following instruction, identify which agent should perform it and extract the clean task.

        Return only a valid JSON object with two keys:
        - "agent": one of ["research_agent", "editor_agent", "writer_agent"]
        - "task": a string with the instruction that the agent should follow

        Only respond with a valid JSON object. Do not include explanations or markdown formatting.

        Instruction: "{step}"
        """
        response = CLIENT.chat.completions.create(
            model=model,
            messages=[{"role": "user", "content": agent_decision_prompt}],
            temperature=0,
        )

        raw_content = response.choices[0].message.content
        cleaned_json = clean_json_block(raw_content)
        agent_info = json.loads(cleaned_json)

        agent_name = agent_info["agent"]
        task = agent_info["task"]

        context = "\n".join([
            f"Step {j+1} executed by {a}:\n{r}" 
            for j, (s, a, r) in enumerate(history)
        ])
        enriched_task = f"""
        You are {agent_name}.

        Here is the context of what has been done so far:
        {context}

        Your next task is:
        {task}
        """

        print(f"\n🛠️ Executing with agent: `{agent_name}` on task: {task}")

        if agent_name in agent_registry:
            output = agent_registry[agent_name](enriched_task)
            history.append((step, agent_name, output))
        else:
            output = f"⚠️ Unknown agent: {agent_name}"
            history.append((step, agent_name, output))

        print(f"✅ Output:\n{output}")

    return history

# %%
# If you want to see the full workflow without limiting the number of steps. Set limit_steps to False
# Keep in mind this could take more than 10 minutes to complete
executor_history = executor_agent("The ensemble Kalman filter for time series forecasting", limit_steps=True)

md = executor_history[-1][-1].strip("`")  
display(Markdown(md))
# Out:
# ==================================
# 🎯 Editor Agent
# ==================================
#
# 🛠️ Executing with agent: `research_agent` on task: Perform a comprehensive search on Web, Wikipedia, and arXiv for 'ensemble Kalman filter' and 'time series forecasting'
# ==================================
# 🔍 Research Agent
# ==================================
# ✅ Output:
#  Here's a comprehensive overview of resources related to the "Ensemble Kalman Filter" and "Time Series Forecasting" from across the web, Wikipedia, and arXiv:
#
# ### Web Resources
#
# 1. **[Time-series prediction using Ensemble Kalman Filter](https://meetingorganizer.copernicus.org/EGU2016/EGU2016-16249.pdf)**
#    - The Ensemble Transform Kalman (ETKF) is applied to ensemble forecasts, analyzing large datasets like the Earth’s magnetic field. It improves prediction skills by integrating observations and behaviors of nearby trajectories, even without a dynamic model.
#
# 2. **[Data Assimilation Using Ensemble Kalman Filter](https://towardsdatascience.com/addressing-the-butterfly-effect-data-assimilation-using-ensemble-kalman-filter-9883d0e1197b)**
#    - Highlights the use of EnKF in data assimilation contexts, focusing on rainfall-runoff models as a time-series prediction problem, illustrating with a simplified bucket model.
#
# 3. **[Understanding the Ensemble Kalman Filter](https://www.math.umd.edu/~slud/RITF17/enkf-tutorial.pdf)**
#    - An introduction to EnKF as a technique for approximate inference in state-space models, typically applied to large spatial fields observed sequentially over time.
#
# 4. **[Ensemble Kalman methods](https://danmackinlay.name/notebook/ensemble_kalman_methods.html)**
#    - Discusses the Kalman filter's implementation in propagating state estimates and covariance matrices, particularly in prediction/forecast steps of dynamic models.
#
# ### Wikipedia
#
# 1. **[Ensemble Kalman filter - Wikipedia](https://en.wikipedia.org/wiki/Ensemble_Kalman_filter)**
#    - Provides an overview of the Ensemble Kalman Filter (EnKF), described as a recursive filter suitable for problems with numerous variables, often used in geophysical models. It connects the Bayesian update problem with ensemble forecasting.
#
# ### arXiv Papers
#
# 1. **[Analyzing the Effects of Observation Function Selection in Ensemble ...](https://arxiv.org/abs/2007.05114)**
#    - Explores the EnKF's role in epidemiological models, demonstrating how observation function choices affect state estimation and forecast predictions.
#
# 2. **[High Dimensional Ensemble Kalman Filter - arXiv](https://arxiv.org/abs/2505.00283)**
#    - Discusses various high-dimensional EnKF methods, focusing on consistent estimators for forecast error covariance and Kalman Gain, with numerical studies illustrating enhanced performance over traditional EnKF.
#
# 3. **[Regularized bias-aware ensemble Kalman filter - arXiv](https://arxiv.org/abs/2306.04315)**
#    - Introduces a framework for bias-aware data assimilation using a regularized EnKF for systems with model biases, showcasing applications relevant to acoustics and vibrations.
#
# 4. **[Ensemble transform Kalman-Bucy filters - arXiv](https://arxiv.org/abs/1103.2235)**
#    - Evaluates Bucy-type formulations in ensemble settings, addressing challenges in integrating ordinary differential equations and maintaining balance in analysis states.
#
# 5. **[Trimmed Ensemble Kalman Filter for Nonlinear and Non-Gaussian Data Assimilation Problems](https://arxiv.org/abs/1808.05465)**
#    - Proposes a Trimmed EnKF that interpolates between distributions of EnKF and particle filters to improve accuracy and efficiency in nonlinear and non-Gaussian data assimilation scenarios.
#
# These resources provide a diverse and thorough examination of the Ensemble Kalman Filter and its application in time series forecasting. They cover theoretical foundations, practical implementations, and advancements in techniques across various domains.
# ✅ Output:
# Here's a comprehensive overview of resources related to the "Ensemble Kalman Filter" and "Time Series Forecasting" from across the web, Wikipedia, and arXiv:
#
# ### Web Resources
#
# 1. **[Time-series prediction using Ensemble Kalman Filter](https://meetingorganizer.copernicus.org/EGU2016/EGU2016-16249.pdf)**
#    - The Ensemble Transform Kalman (ETKF) is applied to ensemble forecasts, analyzing large datasets like the Earth’s magnetic field. It improves prediction skills by integrating observations and behaviors of nearby trajectories, even without a dynamic model.
#
# 2. **[Data Assimilation Using Ensemble Kalman Filter](https://towardsdatascience.com/addressing-the-butterfly-effect-data-assimilation-using-ensemble-kalman-filter-9883d0e1197b)**
#    - Highlights the use of EnKF in data assimilation contexts, focusing on rainfall-runoff models as a time-series prediction problem, illustrating with a simplified bucket model.
#
# 3. **[Understanding the Ensemble Kalman Filter](https://www.math.umd.edu/~slud/RITF17/enkf-tutorial.pdf)**
#    - An introduction to EnKF as a technique for approximate inference in state-space models, typically applied to large spatial fields observed sequentially over time.
#
# 4. **[Ensemble Kalman methods](https://danmackinlay.name/notebook/ensemble_kalman_methods.html)**
#    - Discusses the Kalman filter's implementation in propagating state estimates and covariance matrices, particularly in prediction/forecast steps of dynamic models.
#
# ### Wikipedia
#
# 1. **[Ensemble Kalman filter - Wikipedia](https://en.wikipedia.org/wiki/Ensemble_Kalman_filter)**
#    - Provides an overview of the Ensemble Kalman Filter (EnKF), described as a recursive filter suitable for problems with numerous variables, often used in geophysical models. It connects the Bayesian update problem with ensemble forecasting.
#
# ### arXiv Papers
#
# 1. **[Analyzing the Effects of Observation Function Selection in Ensemble ...](https://arxiv.org/abs/2007.05114)**
#    - Explores the EnKF's role in epidemiological models, demonstrating how observation function choices affect state estimation and forecast predictions.
#
# 2. **[High Dimensional Ensemble Kalman Filter - arXiv](https://arxiv.org/abs/2505.00283)**
#    - Discusses various high-dimensional EnKF methods, focusing on consistent estimators for forecast error covariance and Kalman Gain, with numerical studies illustrating enhanced performance over traditional EnKF.
#
# 3. **[Regularized bias-aware ensemble Kalman filter - arXiv](https://arxiv.org/abs/2306.04315)**
#    - Introduces a framework for bias-aware data assimilation using a regularized EnKF for systems with model biases, showcasing applications relevant to acoustics and vibrations.
#
# 4. **[Ensemble transform Kalman-Bucy filters - arXiv](https://arxiv.org/abs/1103.2235)**
#    - Evaluates Bucy-type formulations in ensemble settings, addressing challenges in integrating ordinary differential equations and maintaining balance in analysis states.
#
# 5. **[Trimmed Ensemble Kalman Filter for Nonlinear and Non-Gaussian Data Assimilation Problems](https://arxiv.org/abs/1808.05465)**
#    - Proposes a Trimmed EnKF that interpolates between distributions of EnKF and particle filters to improve accuracy and efficiency in nonlinear and non-Gaussian data assimilation scenarios.
#
# These resources provide a diverse and thorough examination of the Ensemble Kalman Filter and its application in time series forecasting. They cover theoretical foundations, practical implementations, and advancements in techniques across various domains.
#
# 🛠️ Executing with agent: `research_agent` on task: Identify and select the top ten most relevant research papers on ensemble Kalman filter for time series forecasting
# ==================================
# 🔍 Research Agent
# ==================================
# ✅ Output:
#  Here are the top ten research papers on the Ensemble Kalman Filter (EnKF) for time series forecasting identified from the arXiv search:
#
# 1. **[Analyzing the Effects of Observation Function Selection in Ensemble Kalman Filtering for Epidemic Models](https://arxiv.org/abs/2007.05114)**
#    This paper explores the role of observation functions in the accuracy of the EnKF for state estimation and prediction in epidemiological models.
#
# 2. **[High Dimensional Ensemble Kalman Filter](https://arxiv.org/abs/2505.00283)**
#    Discusses various high-dimensional EnKF methods, focusing on consistent estimators for forecast error covariance and Kalman Gain, enhancing performance over traditional EnKF.
#
# 3. **[Regularized Bias-Aware Ensemble Kalman Filter](https://arxiv.org/abs/2306.04315)**
#    Introduces a framework for bias-aware data assimilation using a regularized EnKF, which estimates bias in both parameters and states in dynamic systems.
#
# 4. **[Ensemble Transform Kalman-Bucy Filters](https://arxiv.org/abs/1103.2235)**
#    Evaluates ensemble settings for Bucy-type formulations in integrating ordinary differential equations, maintaining balance in analysis states.
#
# 5. **[Trimmed Ensemble Kalman Filter for Nonlinear and Non-Gaussian Data Assimilation Problems](https://arxiv.org/abs/1808.05465)**
#    Proposes a Trimmed EnKF that improves accuracy and efficiency in nonlinear and non-Gaussian data assimilation scenarios.
#
# 6. **[Well-Posedness And Accuracy Of The Ensemble Kalman Filter In Discrete And Continuous Time](https://arxiv.org/abs/1310.3167)**
#    Initiates a systematic analysis of the EnKF, focusing on its ability to track signals without diverging.
#
# 7. **[Long-Time Accuracy of Ensemble Kalman Filters for Chaotic and Machine-Learned Dynamical Systems](https://arxiv.org/abs/2412.14318)**
#    Establishes conditions under which the EnKF maintains accuracy over long timescales in chaotic systems and when using surrogate models.
#
# 8. **[Analysis of the Ensemble Kalman Filter for Inverse Problems](https://arxiv.org/abs/1602.02020)**
#    Analyzes applications of EnKF to inverse problems with fixed ensemble sizes, focusing on data assimilation.
#
# 9. **[Nested Ensemble Kalman Filter for Static Parameter Inference](https://arxiv.org/abs/2511.21497)**
#    Discusses the use of EnKF in inferring static parameters within state-space models, providing insights into its adaptability.
#
# 10. **[Trimmed Ensemble Kalman Filter for Nonlinear and Non-Gaussian Data Assimilation Problems](https://arxiv.org/abs/1808.05465)**
#    Presents a method interpolating between EnKF and particle filters, offering control over accuracy and efficiency.
#
# These papers provide insights into the theoretical advancements and practical implementations of EnKF in different forecasting and data assimilation scenarios.
# ✅ Output:
# Here are the top ten research papers on the Ensemble Kalman Filter (EnKF) for time series forecasting identified from the arXiv search:
#
# 1. **[Analyzing the Effects of Observation Function Selection in Ensemble Kalman Filtering for Epidemic Models](https://arxiv.org/abs/2007.05114)**
#    This paper explores the role of observation functions in the accuracy of the EnKF for state estimation and prediction in epidemiological models.
#
# 2. **[High Dimensional Ensemble Kalman Filter](https://arxiv.org/abs/2505.00283)**
#    Discusses various high-dimensional EnKF methods, focusing on consistent estimators for forecast error covariance and Kalman Gain, enhancing performance over traditional EnKF.
#
# 3. **[Regularized Bias-Aware Ensemble Kalman Filter](https://arxiv.org/abs/2306.04315)**
#    Introduces a framework for bias-aware data assimilation using a regularized EnKF, which estimates bias in both parameters and states in dynamic systems.
#
# 4. **[Ensemble Transform Kalman-Bucy Filters](https://arxiv.org/abs/1103.2235)**
#    Evaluates ensemble settings for Bucy-type formulations in integrating ordinary differential equations, maintaining balance in analysis states.
#
# 5. **[Trimmed Ensemble Kalman Filter for Nonlinear and Non-Gaussian Data Assimilation Problems](https://arxiv.org/abs/1808.05465)**
#    Proposes a Trimmed EnKF that improves accuracy and efficiency in nonlinear and non-Gaussian data assimilation scenarios.
#
# 6. **[Well-Posedness And Accuracy Of The Ensemble Kalman Filter In Discrete And Continuous Time](https://arxiv.org/abs/1310.3167)**
#    Initiates a systematic analysis of the EnKF, focusing on its ability to track signals without diverging.
#
# 7. **[Long-Time Accuracy of Ensemble Kalman Filters for Chaotic and Machine-Learned Dynamical Systems](https://arxiv.org/abs/2412.14318)**
#    Establishes conditions under which the EnKF maintains accuracy over long timescales in chaotic systems and when using surrogate models.
#
# 8. **[Analysis of the Ensemble Kalman Filter for Inverse Problems](https://arxiv.org/abs/1602.02020)**
#    Analyzes applications of EnKF to inverse problems with fixed ensemble sizes, focusing on data assimilation.
#
# 9. **[Nested Ensemble Kalman Filter for Static Parameter Inference](https://arxiv.org/abs/2511.21497)**
#    Discusses the use of EnKF in inferring static parameters within state-space models, providing insights into its adaptability.
#
# 10. **[Trimmed Ensemble Kalman Filter for Nonlinear and Non-Gaussian Data Assimilation Problems](https://arxiv.org/abs/1808.05465)**
#    Presents a method interpolating between EnKF and particle filters, offering control over accuracy and efficiency.
#
# These papers provide insights into the theoretical advancements and practical implementations of EnKF in different forecasting and data assimilation scenarios.
#
# 🛠️ Executing with agent: `research_agent` on task: Extract abstracts, key contributions, and methodologies from the selected papers
# ==================================
# 🔍 Research Agent
# ==================================
# ✅ Output:
#  Here are the extracted abstracts, key contributions, and methodologies from the selected papers related to the Ensemble Kalman Filter (EnKF) for time series forecasting:
#
# 1. **Analyzing the Effects of Observation Function Selection in Ensemble Kalman Filtering for Epidemic Models**
#    - **Abstract**: Not available.
#    - **Key Contributions**: This paper explores the role of observation functions in the accuracy of the EnKF for state estimation and prediction in epidemiological models.
#    - **Methodologies**: It discusses various observational functions and analyzes their impact on forecast precision.
#
# 2. **High Dimensional Ensemble Kalman Filter** ([PDF](https://arxiv.org/pdf/2505.00283))
#    - **Abstract**: This paper proposes several high dimensional EnKF (HD-EnKF) methods equipped with consistent estimators for the important forecast error covariance and Kalman Gain matrices. Numerical studies illustrate that these HD-EnKF algorithms outperform the standard EnKF and widely used inflation methods.
#    - **Key Contributions**: Development of HD-EnKF methods that handle high-resolution observations effectively.
#    - **Methodologies**: Theoretical studies and numerical validation on models like Lorenz-96 and Shallow Water Equation.
#
# 3. **Regularized Bias-Aware Ensemble Kalman Filter** ([PDF](https://arxiv.org/pdf/2306.04315))
#    - **Abstract**: Introduces a framework for bias-aware data assimilation using a regularized EnKF, estimating bias in both parameters and states in dynamic systems.
#    - **Key Contributions**: Integrating a model of bias and its gradient to infer systematic errors.
#    - **Methodologies**: Application involves a mathematical solution with an echo state network as a bias estimator and real-time application to nonlinearly coupled oscillators.
#
# 4. **Ensemble Transform Kalman-Bucy Filters** ([PDF](https://arxiv.org/pdf/1103.2235))
#    - **Abstract**: This paper adapts the Kalman-Bucy filter into an ensemble setting using ordinary differential equation representation in pseudo-time.
#    - **Key Contributions**: Proposing transform-based alternatives and evaluating Bucy-type formulations in ensemble settings.
#    - **Methodologies**: Performance evaluation on models like Lorenz-63, Lorenz-96, and SPEEDY atmospheric general circulation model.
#
# 5. **Trimmed Ensemble Kalman Filter for Nonlinear and Non-Gaussian Data Assimilation Problems** ([PDF](https://arxiv.org/pdf/1808.05465))
#    - **Abstract**: Introduces a trimmed ensemble Kalman filter (TEnKF) to balance accuracy and efficiency by removing non-Gaussian outliers.
#    - **Key Contributions**: Offers a method interpolating between EnKF and particle filters, enhancing accuracy and robustness.
#    - **Methodologies**: Demonstrates improvements over traditional EnKF on nonlinear Lorenz-63 and Lorenz-96 models.
#
# 6. **Well-Posedness And Accuracy Of The Ensemble Kalman Filter In Discrete And Continuous Time** ([PDF](https://arxiv.org/pdf/1310.3167))
#    - **Abstract**: Initiates the development of a systematic analysis of the EnKF focusing on well-posedness and accuracy of the filter in discrete and continuous time settings.
#    - **Key Contributions**: Establishing well-posedness without variance inflation and accuracy with variance inflation.
#    - **Methodologies**: Analysis is conducted using the Lorenz models and the Navier-Stokes equation.
#
# 7. **Long-Time Accuracy of Ensemble Kalman Filters for Chaotic and Machine-Learned Dynamical Systems** ([PDF](https://arxiv.org/pdf/2412.14318))
#    - **Abstract**: Establishes conditions under which the EnKF maintains long-time accuracy in chaotic systems and validates use with machine-learned dynamics.
#    - **Key Contributions**: Validating the EnKF's use with surrogate forecast models in chaotic systems.
#    - **Methodologies**: Conditions cover a wide range of partially-observed chaotic systems, including surrogate models.
#
# 8. **Nested Ensemble Kalman Filter for Static Parameter Inference** ([PDF](https://arxiv.org/pdf/2511.21497))
#    - **Abstract**: The paper discusses the use of EnKF in inferring static parameters within state-space models.
#    - **Key Contributions**: Combining reweighting and shifting methods to maintain diversity in sampled states.
#    - **Methodologies**: Extending EnKF with delayed acceptance kernels and nonlinear observation models for parameter inference.
#
# These papers collectively advance the theory and application of EnKF across various domains, improving forecast accuracy and efficiency in complex, high-dimensional systems.
# ✅ Output:
# Here are the extracted abstracts, key contributions, and methodologies from the selected papers related to the Ensemble Kalman Filter (EnKF) for time series forecasting:
#
# 1. **Analyzing the Effects of Observation Function Selection in Ensemble Kalman Filtering for Epidemic Models**
#    - **Abstract**: Not available.
#    - **Key Contributions**: This paper explores the role of observation functions in the accuracy of the EnKF for state estimation and prediction in epidemiological models.
#    - **Methodologies**: It discusses various observational functions and analyzes their impact on forecast precision.
#
# 2. **High Dimensional Ensemble Kalman Filter** ([PDF](https://arxiv.org/pdf/2505.00283))
#    - **Abstract**: This paper proposes several high dimensional EnKF (HD-EnKF) methods equipped with consistent estimators for the important forecast error covariance and Kalman Gain matrices. Numerical studies illustrate that these HD-EnKF algorithms outperform the standard EnKF and widely used inflation methods.
#    - **Key Contributions**: Development of HD-EnKF methods that handle high-resolution observations effectively.
#    - **Methodologies**: Theoretical studies and numerical validation on models like Lorenz-96 and Shallow Water Equation.
#
# 3. **Regularized Bias-Aware Ensemble Kalman Filter** ([PDF](https://arxiv.org/pdf/2306.04315))
#    - **Abstract**: Introduces a framework for bias-aware data assimilation using a regularized EnKF, estimating bias in both parameters and states in dynamic systems.
#    - **Key Contributions**: Integrating a model of bias and its gradient to infer systematic errors.
#    - **Methodologies**: Application involves a mathematical solution with an echo state network as a bias estimator and real-time application to nonlinearly coupled oscillators.
#
# 4. **Ensemble Transform Kalman-Bucy Filters** ([PDF](https://arxiv.org/pdf/1103.2235))
#    - **Abstract**: This paper adapts the Kalman-Bucy filter into an ensemble setting using ordinary differential equation representation in pseudo-time.
#    - **Key Contributions**: Proposing transform-based alternatives and evaluating Bucy-type formulations in ensemble settings.
#    - **Methodologies**: Performance evaluation on models like Lorenz-63, Lorenz-96, and SPEEDY atmospheric general circulation model.
#
# 5. **Trimmed Ensemble Kalman Filter for Nonlinear and Non-Gaussian Data Assimilation Problems** ([PDF](https://arxiv.org/pdf/1808.05465))
#    - **Abstract**: Introduces a trimmed ensemble Kalman filter (TEnKF) to balance accuracy and efficiency by removing non-Gaussian outliers.
#    - **Key Contributions**: Offers a method interpolating between EnKF and particle filters, enhancing accuracy and robustness.
#    - **Methodologies**: Demonstrates improvements over traditional EnKF on nonlinear Lorenz-63 and Lorenz-96 models.
#
# 6. **Well-Posedness And Accuracy Of The Ensemble Kalman Filter In Discrete And Continuous Time** ([PDF](https://arxiv.org/pdf/1310.3167))
#    - **Abstract**: Initiates the development of a systematic analysis of the EnKF focusing on well-posedness and accuracy of the filter in discrete and continuous time settings.
#    - **Key Contributions**: Establishing well-posedness without variance inflation and accuracy with variance inflation.
#    - **Methodologies**: Analysis is conducted using the Lorenz models and the Navier-Stokes equation.
#
# 7. **Long-Time Accuracy of Ensemble Kalman Filters for Chaotic and Machine-Learned Dynamical Systems** ([PDF](https://arxiv.org/pdf/2412.14318))
#    - **Abstract**: Establishes conditions under which the EnKF maintains long-time accuracy in chaotic systems and validates use with machine-learned dynamics.
#    - **Key Contributions**: Validating the EnKF's use with surrogate forecast models in chaotic systems.
#    - **Methodologies**: Conditions cover a wide range of partially-observed chaotic systems, including surrogate models.
#
# 8. **Nested Ensemble Kalman Filter for Static Parameter Inference** ([PDF](https://arxiv.org/pdf/2511.21497))
#    - **Abstract**: The paper discusses the use of EnKF in inferring static parameters within state-space models.
#    - **Key Contributions**: Combining reweighting and shifting methods to maintain diversity in sampled states.
#    - **Methodologies**: Extending EnKF with delayed acceptance kernels and nonlinear observation models for parameter inference.
#
# These papers collectively advance the theory and application of EnKF across various domains, improving forecast accuracy and efficiency in complex, high-dimensional systems.
#
# 🛠️ Executing with agent: `research_agent` on task: Summarize the theoretical foundations of the classical Kalman filter and the ensemble Kalman filter
# ==================================
# 🔍 Research Agent
# ==================================
# ✅ Output:
#  ### Theoretical Foundations
#
# #### Kalman Filter
# - **Overview**: The Kalman filter, also known as linear quadratic estimation, is an algorithm used in statistics and control theory to derive estimates of unknown variables by processing a series of measurements observed over time, including those affected by statistical noise and inaccuracies.
# - **Purpose**: It is designed to produce estimates that are more accurate than those based solely on a single measurement by estimating a joint probability distribution of the variables for each time-step.
# - **Functionality**: The algorithm minimizes mean squared error and relates to maximum likelihood statistics. It operates through a two-phase process: prediction and update.
# - **Applications**: Widely used for guidance, navigation, and control of vehicles (such as aircraft and spacecraft), time series analysis (e.g., signal processing and econometrics), and robotic motion planning and control. It models the central nervous system's movement control, providing estimates of the current state in motor system control.
# - **Algorithm Process**: It involves a prediction phase, where the current state is projected forward, and an update phase, where new measurements are incorporated to refine estimates.
#
# For more detailed information, visit the [Kalman filter Wikipedia page](https://en.wikipedia.org/wiki/Kalman_filter).
#
# #### Ensemble Kalman Filter (EnKF)
# - **Overview**: The Ensemble Kalman Filter is a recursive filter suitable for problems with a large number of variables, making it ideal for applications involving the discretization of partial differential equations in geophysical models.
# - **Origin**: Developed as a version of the classical Kalman filter for large problems by replacing the covariance matrix with a sample covariance.
# - **EnKF's Role**: An important component in data assimilation and ensemble forecasting, it functions as a Monte Carlo implementation of the Bayesian update problem, making Bayesian updates using an ensemble of state vectors.
# - **Comparison**: Related to the particle filter, it assumes all probability distributions are Gaussian, allowing more computational efficiency than particle filters when applicable.
# - **Mechanism**: EnKF employs state vectors (ensemble members) to represent the system state distribution, replacing the often computationally prohibitive covariance matrix with sample covariances.
# - **Functionality**: Combines the Bayesian update for the model state with periodic new data assimilation, facilitating model advancement over time while maintaining an ensemble of possible states.
#
# For deeper insights, visit the [Ensemble Kalman filter Wikipedia page](https://en.wikipedia.org/wiki/Ensemble_Kalman_filter).
# ✅ Output:
# ### Theoretical Foundations
#
# #### Kalman Filter
# - **Overview**: The Kalman filter, also known as linear quadratic estimation, is an algorithm used in statistics and control theory to derive estimates of unknown variables by processing a series of measurements observed over time, including those affected by statistical noise and inaccuracies.
# - **Purpose**: It is designed to produce estimates that are more accurate than those based solely on a single measurement by estimating a joint probability distribution of the variables for each time-step.
# - **Functionality**: The algorithm minimizes mean squared error and relates to maximum likelihood statistics. It operates through a two-phase process: prediction and update.
# - **Applications**: Widely used for guidance, navigation, and control of vehicles (such as aircraft and spacecraft), time series analysis (e.g., signal processing and econometrics), and robotic motion planning and control. It models the central nervous system's movement control, providing estimates of the current state in motor system control.
# - **Algorithm Process**: It involves a prediction phase, where the current state is projected forward, and an update phase, where new measurements are incorporated to refine estimates.
#
# For more detailed information, visit the [Kalman filter Wikipedia page](https://en.wikipedia.org/wiki/Kalman_filter).
#
# #### Ensemble Kalman Filter (EnKF)
# - **Overview**: The Ensemble Kalman Filter is a recursive filter suitable for problems with a large number of variables, making it ideal for applications involving the discretization of partial differential equations in geophysical models.
# - **Origin**: Developed as a version of the classical Kalman filter for large problems by replacing the covariance matrix with a sample covariance.
# - **EnKF's Role**: An important component in data assimilation and ensemble forecasting, it functions as a Monte Carlo implementation of the Bayesian update problem, making Bayesian updates using an ensemble of state vectors.
# - **Comparison**: Related to the particle filter, it assumes all probability distributions are Gaussian, allowing more computational efficiency than particle filters when applicable.
# - **Mechanism**: EnKF employs state vectors (ensemble members) to represent the system state distribution, replacing the often computationally prohibitive covariance matrix with sample covariances.
# - **Functionality**: Combines the Bayesian update for the model state with periodic new data assimilation, facilitating model advancement over time while maintaining an ensemble of possible states.
#
# For deeper insights, visit the [Ensemble Kalman filter Wikipedia page](https://en.wikipedia.org/wiki/Ensemble_Kalman_filter).
# ### Theoretical Foundations
#
# #### Kalman Filter
# - **Overview**: The Kalman filter, also known as linear quadratic estimation, is an algorithm used in statistics and control theory to derive estimates of unknown variables by processing a series of measurements observed over time, including those affected by statistical noise and inaccuracies.
# - **Purpose**: It is designed to produce estimates that are more accurate than those based solely on a single measurement by estimating a joint probability distribution of the variables for each time-step.
# - **Functionality**: The algorithm minimizes mean squared error and relates to maximum likelihood statistics. It operates through a two-phase process: prediction and update.
# - **Applications**: Widely used for guidance, navigation, and control of vehicles (such as aircraft and spacecraft), time series analysis (e.g., signal processing and econometrics), and robotic motion planning and control. It models the central nervous system's movement control, providing estimates of the current state in motor system control.
# - **Algorithm Process**: It involves a prediction phase, where the current state is projected forward, and an update phase, where new measurements are incorporated to refine estimates.
#
# For more detailed information, visit the [Kalman filter Wikipedia page](https://en.wikipedia.org/wiki/Kalman_filter).
#
# #### Ensemble Kalman Filter (EnKF)
# - **Overview**: The Ensemble Kalman Filter is a recursive filter suitable for problems with a large number of variables, making it ideal for applications involving the discretization of partial differential equations in geophysical models.
# - **Origin**: Developed as a version of the classical Kalman filter for large problems by replacing the covariance matrix with a sample covariance.
# - **EnKF's Role**: An important component in data assimilation and ensemble forecasting, it functions as a Monte Carlo implementation of the Bayesian update problem, making Bayesian updates using an ensemble of state vectors.
# - **Comparison**: Related to the particle filter, it assumes all probability distributions are Gaussian, allowing more computational efficiency than particle filters when applicable.
# - **Mechanism**: EnKF employs state vectors (ensemble members) to represent the system state distribution, replacing the often computationally prohibitive covariance matrix with sample covariances.
# - **Functionality**: Combines the Bayesian update for the model state with periodic new data assimilation, facilitating model advancement over time while maintaining an ensemble of possible states.
#
# For deeper insights, visit the [Ensemble Kalman filter Wikipedia page](https://en.wikipedia.org/wiki/Ensemble_Kalman_filter).
