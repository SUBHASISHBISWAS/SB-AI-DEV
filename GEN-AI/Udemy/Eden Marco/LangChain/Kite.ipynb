# %%
import os
import smtplib
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart
from datetime import datetime
import json

# For Kite API - Install: pip install kiteconnect
from kiteconnect import KiteConnect

kite = KiteConnect(api_key="v1akibrmbpopgviv")
kite.set_access_token("FutuNFXFrZneEiPhiCjEjkNNklJj5k42")
kite.profile()
# Out:
# {'user_id': 'HJL242',
#  'user_type': 'individual/ind_with_nom',
#  'email': 'subhasishbiswas15@gmail.com',
#  'user_name': 'Subhasish Biswas',
#  'user_shortname': 'Subhasish',
#  'broker': 'ZERODHA',
#  'exchanges': ['BCD', 'NFO', 'NSE', 'BSE', 'MF', 'BFO'],
#  'products': ['CNC', 'NRML', 'MIS', 'BO', 'CO'],
#  'order_types': ['MARKET', 'LIMIT', 'SL', 'SL-M'],
#  'avatar_url': 'https://s3.ap-south-1.amazonaws.com/zerodha-kite-blobs/avatars/bnAbkij5Jwlnxv0SpymmJBtthRYOGFfo.png',
#  'meta': {'demat_consent': 'ddpi'}}
