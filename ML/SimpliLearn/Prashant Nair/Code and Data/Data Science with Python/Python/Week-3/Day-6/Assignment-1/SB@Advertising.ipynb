# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv("Advertising.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
# Unnamed: 0    200 non-null int64
# TV            200 non-null float64
# radio         200 non-null float64
# newspaper     200 non-null float64
# sales         200 non-null float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %%
df.head()
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
#Since There no missing data so start EDA
'''
TV            200 non-null float64--->Numerical--->Quantative--->histogram
radio         200 non-null float64--->Numerical--->Quantative--->histogram
newspaper     200 non-null float64--->Numerical--->Quantative--->histogram
sales         200 non-null float64--->Numerical--->Quantative--->histogram
'''
# Out:
# '\nTV            200 non-null float64--->Numerical--->Quantative--->histogram\nradio         200 non-null float64--->Numerical--->Quantative--->histogram\nnewspaper     200 non-null float64--->Numerical--->Quantative--->histogram\nsales         200 non-null float64--->Numerical--->Quantative--->histogram\n'

# %%
#Quantative Analysis
#Mesure of Central Tendency

df.describe()
#Measure of Dispersion
#df.TV.plot(kind='hist')
# Out:
#        Unnamed: 0          TV       radio   newspaper       sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# 75%    150.250000  218.825000   36.525000   45.100000   17.400000
# max    200.000000  296.400000   49.600000  114.000000   27.000000

# %%
df.TV.plot(kind='hist')

# %%
#Data Stribution
sns.pairplot(df)

#X Axis -Feature
#Y- Label

# %%
#Feture TV	radio	newspaper
#Labe ->sales
#There Is Correlation Between Feature and Label
#Regression Problem
df.corr()
# Out:
#             Unnamed: 0        TV     radio  newspaper     sales
# Unnamed: 0    1.000000  0.017715 -0.110680  -0.154944 -0.051616
# TV            0.017715  1.000000  0.054809   0.056648  0.782224
# radio        -0.110680  0.054809  1.000000   0.354104  0.576223
# newspaper    -0.154944  0.056648  0.354104   1.000000  0.228299
# sales        -0.051616  0.782224  0.576223   0.228299  1.000000

# %%
#TV-Sales and radio have strong Correletion (linera realtionship)
#Final Feture ->TV, Radio
