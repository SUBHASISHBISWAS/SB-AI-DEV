# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
socialNetworkAdsData = pd.read_csv('Data/Social_Network_Ads.csv')

# %%
socialNetworkAdsData.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
socialNetworkAdsData.corr()
# Out:
#                   User ID       Age  EstimatedSalary  Purchased
# User ID          1.000000 -0.000721         0.071097   0.007120
# Age             -0.000721  1.000000         0.155238   0.622454
# EstimatedSalary  0.071097  0.155238         1.000000   0.362083
# Purchased        0.007120  0.622454         0.362083   1.000000

# %%
sns.pairplot(socialNetworkAdsData)

# %%
#Feature and Label Creation
features =socialNetworkAdsData.iloc[:,[2,3]].values
label=socialNetworkAdsData.iloc[:,3]

# %%
#Training and Test Data Preparation 
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(features,
                                                label,
                                                test_size = 0.3,
                                                random_state=7)

# %%
#Model Creation
from sklearn.neighbors import KNeighborsClassifier
model=KNeighborsClassifier(n_neighbors=10)
model.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=10, p=2,
#            weights='uniform')

# %%
model.score(X_train,y_train)
# Out:
# 0.475

# %%
model.score(X_test,y_test)
# Out:
# 0.4166666666666667
