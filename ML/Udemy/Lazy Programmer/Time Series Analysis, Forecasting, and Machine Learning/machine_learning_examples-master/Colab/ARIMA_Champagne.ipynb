# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.metrics import r2_score

# %%
# !pip install -U statsmodels
# Out:
# Collecting statsmodels
#   Downloading https://files.pythonhosted.org/packages/da/69/8eef30a6237c54f3c0b524140e2975f4b1eea3489b45eb3339574fc8acee/statsmodels-0.12.2-cp37-cp37m-manylinux1_x86_64.whl (9.5MB)
#      |████████████████████████████████| 9.5MB 6.0MB/s
# Requirement already satisfied, skipping upgrade: scipy>=1.1 in /usr/local/lib/python3.7/dist-packages (from statsmodels) (1.4.1)
# Requirement already satisfied, skipping upgrade: patsy>=0.5 in /usr/local/lib/python3.7/dist-packages (from statsmodels) (0.5.1)
# Requirement already satisfied, skipping upgrade: pandas>=0.21 in /usr/local/lib/python3.7/dist-packages (from statsmodels) (1.1.5)
# Requirement already satisfied, skipping upgrade: numpy>=1.15 in /usr/local/lib/python3.7/dist-packages (from statsmodels) (1.19.5)
# Requirement already satisfied, skipping upgrade: six in /usr/local/lib/python3.7/dist-packages (from patsy>=0.5->statsmodels) (1.15.0)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.21->statsmodels) (2.8.1)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.21->statsmodels) (2018.9)
# Installing collected packages: statsmodels
#   Found existing installation: statsmodels 0.10.2
#     Uninstalling statsmodels-0.10.2:
#       Successfully uninstalled statsmodels-0.10.2
# Successfully installed statsmodels-0.12.2

# %%
# !pip install pmdarima
# Out:
# Collecting pmdarima
#   Downloading https://files.pythonhosted.org/packages/f4/c2/2a94bce6bba1deac3c0b16dbb14f28de0b9035e3211919cae8448455aa65/pmdarima-1.8.2-cp37-cp37m-manylinux1_x86_64.whl (1.5MB)
#      |████████████████████████████████| 1.5MB 6.8MB/s
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (0.22.2.post1)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.1.5)
# Requirement already satisfied: statsmodels!=0.12.0,>=0.11 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (0.12.2)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.0.1)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.4.1)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (56.1.0)
# Requirement already satisfied: Cython!=0.29.18,>=0.29 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (0.29.23)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.24.3)
# Requirement already satisfied: numpy~=1.19.0 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.19.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19->pmdarima) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19->pmdarima) (2018.9)
# Requirement already satisfied: patsy>=0.5 in /usr/local/lib/python3.7/dist-packages (from statsmodels!=0.12.0,>=0.11->pmdarima) (0.5.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.19->pmdarima) (1.15.0)
# Installing collected packages: pmdarima
# Successfully installed pmdarima-1.8.2

# %%
# !wget -nc https://lazyprogrammer.me/course_files/timeseries/perrin-freres-monthly-champagne.csv
# Out:
# --2021-05-29 23:22:46--  https://lazyprogrammer.me/course_files/timeseries/perrin-freres-monthly-champagne.csv
# Resolving lazyprogrammer.me (lazyprogrammer.me)... 104.21.23.210, 172.67.213.166, 2606:4700:3031::6815:17d2, ...
# Connecting to lazyprogrammer.me (lazyprogrammer.me)|104.21.23.210|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1598 (1.6K) [text/csv]
# Saving to: ‘perrin-freres-monthly-champagne.csv’
#
# perrin-freres-month 100%[===================>]   1.56K  --.-KB/s    in 0s
#
# 2021-05-29 23:22:46 (27.1 MB/s) - ‘perrin-freres-monthly-champagne.csv’ saved [1598/1598]

# %%
df = pd.read_csv(
    'perrin-freres-monthly-champagne.csv',
    index_col='Month',
    skipfooter=2,
    parse_dates=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   """

# %%
df.head()
# Out:
#             Perrin Freres monthly champagne sales millions ?64-?72
# Month
# 1964-01-01                                               2815
# 1964-02-01                                               2672
# 1964-03-01                                               2755
# 1964-04-01                                               2721
# 1964-05-01                                               2946

# %%
df.columns = ['Sales']

# %%
df['Sales'].plot();

# %%
df['LogSales'] = np.log(df['Sales'])
df['LogSales'].plot();

# %%
df.index.freq = 'MS'

# %%
Ntest = 12
train = df.iloc[:-Ntest]
test = df.iloc[-Ntest:]

# %%
# boolean series to index df rows
train_idx = df.index <= train.index[-1]
test_idx = df.index > train.index[-1]

# %%
import pmdarima as pm

# %%
model = pm.auto_arima(train['LogSales'],
                      trace=True,
                      suppress_warnings=True,
                      seasonal=True, m=12)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,1,1)[12] intercept   : AIC=-50.266, Time=2.01 sec
#  ARIMA(0,0,0)(0,1,0)[12] intercept   : AIC=-41.975, Time=0.04 sec
#  ARIMA(1,0,0)(1,1,0)[12] intercept   : AIC=-54.968, Time=0.47 sec
#  ARIMA(0,0,1)(0,1,1)[12] intercept   : AIC=-53.384, Time=0.40 sec
#  ARIMA(0,0,0)(0,1,0)[12]             : AIC=-34.700, Time=0.02 sec
#  ARIMA(1,0,0)(0,1,0)[12] intercept   : AIC=-44.102, Time=0.06 sec
#  ARIMA(1,0,0)(2,1,0)[12] intercept   : AIC=-52.971, Time=1.20 sec
#  ARIMA(1,0,0)(1,1,1)[12] intercept   : AIC=-52.991, Time=0.65 sec
#  ARIMA(1,0,0)(0,1,1)[12] intercept   : AIC=-55.117, Time=0.41 sec
#  ARIMA(1,0,0)(0,1,2)[12] intercept   : AIC=-53.123, Time=0.89 sec
#  ARIMA(1,0,0)(1,1,2)[12] intercept   : AIC=inf, Time=3.05 sec
#  ARIMA(0,0,0)(0,1,1)[12] intercept   : AIC=-50.817, Time=0.38 sec
#  ARIMA(2,0,0)(0,1,1)[12] intercept   : AIC=-56.123, Time=0.59 sec
#  ARIMA(2,0,0)(0,1,0)[12] intercept   : AIC=-44.178, Time=0.11 sec
#  ARIMA(2,0,0)(1,1,1)[12] intercept   : AIC=-54.128, Time=1.26 sec
#  ARIMA(2,0,0)(0,1,2)[12] intercept   : AIC=-54.125, Time=1.25 sec
#  ARIMA(2,0,0)(1,1,0)[12] intercept   : AIC=-55.720, Time=0.50 sec
#  ARIMA(2,0,0)(1,1,2)[12] intercept   : AIC=inf, Time=2.76 sec
#  ARIMA(3,0,0)(0,1,1)[12] intercept   : AIC=-55.723, Time=0.49 sec
#  ARIMA(2,0,1)(0,1,1)[12] intercept   : AIC=-55.835, Time=0.76 sec
#  ARIMA(1,0,1)(0,1,1)[12] intercept   : AIC=-57.834, Time=0.94 sec
#  ARIMA(1,0,1)(0,1,0)[12] intercept   : AIC=-45.579, Time=0.27 sec
#  ARIMA(1,0,1)(1,1,1)[12] intercept   : AIC=-55.833, Time=1.36 sec
#  ARIMA(1,0,1)(0,1,2)[12] intercept   : AIC=-55.838, Time=2.13 sec
#  ARIMA(1,0,1)(1,1,0)[12] intercept   : AIC=-57.407, Time=0.82 sec
#  ARIMA(1,0,1)(1,1,2)[12] intercept   : AIC=-54.918, Time=2.75 sec
#  ARIMA(1,0,2)(0,1,1)[12] intercept   : AIC=-55.850, Time=1.44 sec
#  ARIMA(0,0,2)(0,1,1)[12] intercept   : AIC=-53.608, Time=0.56 sec
#  ARIMA(2,0,2)(0,1,1)[12] intercept   : AIC=-53.068, Time=1.71 sec
#  ARIMA(1,0,1)(0,1,1)[12]             : AIC=-56.684, Time=1.00 sec
#
# Best model:  ARIMA(1,0,1)(0,1,1)[12] intercept
# Total fit time: 30.414 seconds

# %%
# Since the model is seasonal, we won't plot or predict the first 12
# values (since pmdarima will set them to 0)
train_pred = model.predict_in_sample(start=12, end=-1)
test_pred, confint = model.predict(n_periods=Ntest, return_conf_int=True)

fig, ax = plt.subplots(figsize=(10, 5))
ax.plot(df.index, df['LogSales'], label='data')
ax.plot(train.index[12:], train_pred, label='fitted')
ax.plot(test.index, test_pred, label='forecast')
ax.fill_between(test.index, \
                confint[:,0], confint[:,1], \
                color='red', alpha=0.3)
ax.legend();

# %%
# Compute R^2
r2_score(test['Sales'], np.exp(test_pred))
# Out:
# 0.9546942228798783

# %%
# Best non-seasonal model
model = pm.auto_arima(train['LogSales'],
                      trace=True,
                      max_p=12, max_q=2, max_order=14,
                      suppress_warnings=True,
                      stepwise=False,
                      seasonal=False)
# Out:
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=141.911, Time=0.05 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.27 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.36 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=141.540, Time=0.05 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.37 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.40 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=139.851, Time=0.06 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.41 sec
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.24 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=138.023, Time=0.10 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.60 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.40 sec
#  ARIMA(4,1,0)(0,0,0)[0] intercept   : AIC=114.336, Time=0.11 sec
#  ARIMA(4,1,1)(0,0,0)[0] intercept   : AIC=114.576, Time=0.26 sec
#  ARIMA(4,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.64 sec
#  ARIMA(5,1,0)(0,0,0)[0] intercept   : AIC=114.173, Time=0.18 sec
#  ARIMA(5,1,1)(0,0,0)[0] intercept   : AIC=116.168, Time=0.35 sec
#  ARIMA(5,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.74 sec
#  ARIMA(6,1,0)(0,0,0)[0] intercept   : AIC=116.155, Time=0.24 sec
#  ARIMA(6,1,1)(0,0,0)[0] intercept   : AIC=118.024, Time=0.39 sec
#  ARIMA(6,1,2)(0,0,0)[0] intercept   : AIC=106.730, Time=0.81 sec
#  ARIMA(7,1,0)(0,0,0)[0] intercept   : AIC=112.569, Time=0.29 sec
#  ARIMA(7,1,1)(0,0,0)[0] intercept   : AIC=104.790, Time=0.46 sec
#  ARIMA(7,1,2)(0,0,0)[0] intercept   : AIC=107.741, Time=0.85 sec
#  ARIMA(8,1,0)(0,0,0)[0] intercept   : AIC=85.830, Time=0.48 sec
#  ARIMA(8,1,1)(0,0,0)[0] intercept   : AIC=56.518, Time=0.97 sec
#  ARIMA(8,1,2)(0,0,0)[0] intercept   : AIC=36.833, Time=1.08 sec
#  ARIMA(9,1,0)(0,0,0)[0] intercept   : AIC=83.083, Time=0.57 sec
#  ARIMA(9,1,1)(0,0,0)[0] intercept   : AIC=56.836, Time=1.14 sec
#  ARIMA(9,1,2)(0,0,0)[0] intercept   : AIC=60.427, Time=1.20 sec
#  ARIMA(10,1,0)(0,0,0)[0] intercept   : AIC=65.099, Time=0.87 sec
#  ARIMA(10,1,1)(0,0,0)[0] intercept   : AIC=38.178, Time=1.37 sec
#  ARIMA(10,1,2)(0,0,0)[0] intercept   : AIC=13.496, Time=1.49 sec
#  ARIMA(11,1,0)(0,0,0)[0] intercept   : AIC=inf, Time=1.51 sec
#  ARIMA(11,1,1)(0,0,0)[0] intercept   : AIC=-16.175, Time=1.50 sec
#  ARIMA(11,1,2)(0,0,0)[0] intercept   : AIC=-17.492, Time=1.74 sec
#  ARIMA(12,1,0)(0,0,0)[0] intercept   : AIC=inf, Time=1.75 sec
#  ARIMA(12,1,1)(0,0,0)[0] intercept   : AIC=-19.814, Time=1.92 sec
#  ARIMA(12,1,2)(0,0,0)[0] intercept   : AIC=-17.680, Time=1.95 sec
#
# Best model:  ARIMA(12,1,1)(0,0,0)[0] intercept
# Total fit time: 28.241 seconds

# %%
train_pred = model.predict_in_sample(start=1, end=-1)
test_pred, confint = model.predict(n_periods=Ntest, return_conf_int=True)

fig, ax = plt.subplots(figsize=(10, 5))
ax.plot(df.index, df['LogSales'], label='data')
ax.plot(train.index[1:], train_pred, label='fitted')
ax.plot(test.index, test_pred, label='forecast')
ax.fill_between(test.index, \
                confint[:,0], confint[:,1], \
                color='red', alpha=0.3)
ax.legend();

# %%
r2_score(test['Sales'], np.exp(test_pred))
# Out:
# 0.9716946486242174

# %%
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
plot_acf(df['LogSales']);

# %%
# You'll get a weird sqrt error with default method
plot_pacf(df['LogSales'], method='ols');

# %%
df['LogSales'].diff().plot();

# %%
plot_acf(df['LogSales'].diff().dropna());

# %%
plot_pacf(df['LogSales'].diff().dropna(), method='ols');

# %%
from statsmodels.tsa.stattools import adfuller

# %%
adfuller(df['LogSales'])
# Out:
# (-2.255118601284435,
#  0.18685173111687048,
#  13,
#  91,
#  {'1%': -3.50434289821397,
#   '10%': -2.5840147047458037,
#   '5%': -2.8938659630479413},
#  -49.191437515830046)

# %%
adfuller(df['LogSales'].diff().dropna())
# Out:
# (-4.460914465253633,
#  0.0002312140464953588,
#  12,
#  91,
#  {'1%': -3.50434289821397,
#   '10%': -2.5840147047458037,
#   '5%': -2.8938659630479413},
#  -43.63799632128652)

# %%
# from previous
def plot_fit_and_forecast(result, d=0, col='Sales'):
  fig, ax = plt.subplots(figsize=(10, 5))
  ax.plot(df[col], label='data')

  # plot the curve fitted on train set
  train_pred = result.fittedvalues
  ax.plot(train.index[d:], train_pred[d:], color='green', label='fitted')

  # forecast the test set
  prediction_result = result.get_forecast(Ntest)
  conf_int = prediction_result.conf_int()
  lower, upper = conf_int[f'lower {col}'], conf_int[f'upper {col}']
  forecast = prediction_result.predicted_mean
  ax.plot(test.index, forecast, label='forecast')
  ax.fill_between(test.index, \
                  lower, upper, \
                  color='red', alpha=0.3)
  ax.legend()

  return forecast

# %%
arima = ARIMA(train['LogSales'], order=(12,1,2))
arima_result = arima.fit()
forecast = plot_fit_and_forecast(arima_result, d=1, col='LogSales')
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)

# %%
r2_score(test['Sales'], np.exp(forecast))
# Out:
# 0.9866622810089092
